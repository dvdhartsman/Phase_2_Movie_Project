# %% [markdown]
# # Hello, this is project 2

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sqlite3
from zipfile import ZipFile # for unzipping the db.zip file
pd.set_option('display.max_columns', None) # show all columns when printing out dataframe
plt.style.use("fivethirtyeight")
import scipy.stats as stats

from mpl_toolkits import mplot3d
import sklearn.metrics as metrics
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Idk why im having a problem, but hopefully this will fix it

# %% [markdown]
# # BOM GROSS has title, year, dom_gross, foreign_gross, SO good earnings metrics

# %%
bom_gross_df = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
bom_gross_df.head()
#bom_gross_df.info()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
bom_gross_df.shape
# Out:
# (3387, 5)

# %% [markdown]
# foreign_gross is listed as an object

# %% [markdown]
# ### Need to convert foreign gross, and handle null entries... thinking of just dropping missing gross values

# %%
bom_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
bom_gross_df.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
bom_gross_df['foreign_gross'].str.isnumeric().sum()
# Out:
# 2032

# %% [markdown]
# ## Filling NaN's in domestic gross and foreign_gross /w zeros for now

# %%
bom_gross_df['domestic_gross'].fillna(0, inplace=True)

# %%
bom_gross_df['foreign_gross'].fillna(0, inplace=True)

# %%
bom_gross_df.sort_values(by='domestic_gross', ascending=False)
# Out:
#                                title studio  domestic_gross foreign_gross  \
# 1872    Star Wars: The Force Awakens     BV     936700000.0       1,131.6
# 3080                   Black Panther     BV     700100000.0     646900000
# 3079          Avengers: Infinity War     BV     678800000.0       1,369.5
# 1873                  Jurassic World   Uni.     652300000.0       1,019.4
# 727            Marvel's The Avengers     BV     623400000.0     895500000
# ...                              ...    ...             ...           ...
# 936              Lula, Son of Brazil   NYer             0.0       3800000
# 1079                  The Green Wave     RF             0.0         70100
# 1975  Surprise - Journey To The West     AR             0.0      49600000
# 966                   The Cup (2012)   Myr.             0.0       1800000
# 537                            Force   FoxS             0.0       4800000
#
#       year
# 1872  2015
# 3080  2018
# 3079  2018
# 1873  2015
# 727   2012
# ...    ...
# 936   2012
# 1079  2012
# 1975  2015
# 966   2012
# 537   2011
#
# [3387 rows x 5 columns]

# %%
# There were 1350 null values, now none
bom_gross_df.loc[bom_gross_df['foreign_gross'].isnull()]
# Out:
# Empty DataFrame
# Columns: [title, studio, domestic_gross, foreign_gross, year]
# Index: []

# %%
numeric_values = pd.to_numeric(bom_gross_df['foreign_gross'], errors='coerce')
numeric_values.head()
# Out:
# 0    652000000.0
# 1    691300000.0
# 2    664300000.0
# 3    535700000.0
# 4    513900000.0
# Name: foreign_gross, dtype: float64

# %%
filtered_df = bom_gross_df[numeric_values.notnull()]

# %%
filtered_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
filtered_df['foreign_gross']
# Out:
# 0       652000000
# 1       691300000
# 2       664300000
# 3       535700000
# 4       513900000
#           ...
# 3382            0
# 3383            0
# 3384            0
# 3385            0
# 3386            0
# Name: foreign_gross, Length: 3382, dtype: object

# %%
filtered_df['foreign_gross'].isna().sum()
# Out:
# 0

# %% [markdown]
# # THIS IS THE WAY TO AVOID SETTING TO COPY, LOL NOT!

# %%
filtered_df['foreign_gross'] = pd.to_numeric(filtered_df['foreign_gross'], errors='coerce')
# Out:
# <ipython-input-16-8df85d225cb7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['foreign_gross'] = pd.to_numeric(filtered_df['foreign_gross'], errors='coerce')

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3382 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3382 non-null   object
#  1   studio          3377 non-null   object
#  2   domestic_gross  3382 non-null   float64
#  3   foreign_gross   3382 non-null   int64
#  4   year            3382 non-null   int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 158.5+ KB

# %%
filtered_df.sort_values(by='foreign_gross', ascending=False)[:5]
# Out:
#                                             title studio  domestic_gross  \
# 328   Harry Potter and the Deathly Hallows Part 2     WB     381000000.0
# 1875                      Avengers: Age of Ultron     BV     459000000.0
# 727                         Marvel's The Avengers     BV     623400000.0
# 3081               Jurassic World: Fallen Kingdom   Uni.     417700000.0
# 1127                                       Frozen     BV     400700000.0
#
#       foreign_gross  year
# 328       960500000  2011
# 1875      946400000  2015
# 727       895500000  2012
# 3081      891800000  2018
# 1127      875700000  2013

# %%
filtered_df[filtered_df['title'].str.contains("Avengers")]
# Out:
#                         title studio  domestic_gross  foreign_gross  year
# 727     Marvel's The Avengers     BV     623400000.0      895500000  2012
# 1875  Avengers: Age of Ultron     BV     459000000.0      946400000  2015

# %% [markdown]
# # 2010 is earliest year on record

# %%
filtered_df['year'].min()
# Out:
# 2010

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3382 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3382 non-null   object
#  1   studio          3377 non-null   object
#  2   domestic_gross  3382 non-null   float64
#  3   foreign_gross   3382 non-null   int64
#  4   year            3382 non-null   int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 158.5+ KB

# %%
filtered_df.loc[filtered_df['foreign_gross'] > 0].sort_values(by='foreign_gross', ascending=False)
# Out:
#                                              title   studio  domestic_gross  \
# 328    Harry Potter and the Deathly Hallows Part 2       WB     381000000.0
# 1875                       Avengers: Age of Ultron       BV     459000000.0
# 727                          Marvel's The Avengers       BV     623400000.0
# 3081                Jurassic World: Fallen Kingdom     Uni.     417700000.0
# 1127                                        Frozen       BV     400700000.0
# ...                                            ...      ...             ...
# 327                             Aashayein (Wishes)  Relbig.             0.0
# 290   Client 9: The Rise and Fall of Eliot Spitzer    Magn.        189000.0
# 316                                  The Red Baron    Mont.         37200.0
# 721                              To Die Like a Man   Strand          4000.0
# 921                              Chasing Mavericks      Fox       6000000.0
#
#       foreign_gross  year
# 328       960500000  2011
# 1875      946400000  2015
# 727       895500000  2012
# 3081      891800000  2018
# 1127      875700000  2013
# ...             ...   ...
# 327            3800  2010
# 290            3500  2010
# 316            3100  2010
# 721             900  2011
# 921             600  2012
#
# [2032 rows x 5 columns]

# %% [markdown]
# # Making a new df object for movies grossing more than $1M domestically

# %%
bom_df = filtered_df.loc[(filtered_df['domestic_gross'] > 1000000)].copy()

# %%
bom_df.sort_values(by="domestic_gross", ascending=False)[:10]
# Out:
#                                 title studio  domestic_gross  foreign_gross  \
# 3080                    Black Panther     BV     700100000.0      646900000
# 727             Marvel's The Avengers     BV     623400000.0      895500000
# 2758         Star Wars: The Last Jedi     BV     620200000.0      712400000
# 3082                    Incredibles 2     BV     608600000.0      634200000
# 2323     Rogue One: A Star Wars Story     BV     532200000.0      523900000
# 2759      Beauty and the Beast (2017)     BV     504000000.0      759500000
# 2324                     Finding Dory     BV     486300000.0      542300000
# 1875          Avengers: Age of Ultron     BV     459000000.0      946400000
# 729             The Dark Knight Rises     WB     448100000.0      636800000
# 1131  The Hunger Games: Catching Fire    LGF     424700000.0      440300000
#
#       year
# 3080  2018
# 727   2012
# 2758  2017
# 3082  2018
# 2323  2016
# 2759  2017
# 2324  2016
# 1875  2015
# 729   2012
# 1131  2013

# %%
bom_df.year.agg(['max', 'min', 'mean'])  # 2010-2018
# Out:
# max     2018.000000
# min     2010.000000
# mean    2014.007374
# Name: year, dtype: float64

# %%
bom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1763 entries, 0 to 3281
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           1763 non-null   object
#  1   studio          1763 non-null   object
#  2   domestic_gross  1763 non-null   float64
#  3   foreign_gross   1763 non-null   int64
#  4   year            1763 non-null   int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 82.6+ KB

# %%
# in_mills = (bom_df.loc[:, 'domestic_gross'] / 1000000)

# %%
# bom_df.loc[:, 'domestic_gross'] = in_mills.copy()

# %%
bom_df['domestic_gross'] = (bom_df['domestic_gross'] / 1000000)

# %%
bom_df['domestic_gross'].sort_values(ascending=False)
# Out:
# 3080    700.1
# 727     623.4
# 2758    620.2
# 3082    608.6
# 2323    532.2
#         ...
# 991       1.1
# 588       1.1
# 589       1.1
# 1734      1.1
# 1360      1.1
# Name: domestic_gross, Length: 1763, dtype: float64

# %%
bom_df['foreign_gross'] = (bom_df['foreign_gross'] / 1000000)

# %%
bom_df['foreign_gross'].sort_values(ascending=False)
# Out:
# 328     960.5
# 1875    946.4
# 727     895.5
# 3081    891.8
# 1127    875.7
#         ...
# 1717      0.0
# 2524      0.0
# 2523      0.0
# 2522      0.0
# 3281      0.0
# Name: foreign_gross, Length: 1763, dtype: float64

# %% [markdown]
# # Failed attempts at assignment because .loc was unneccessary

# %%
# bom_df.loc[:, 'domestic_gross'] = bom_df['domestic_gross'] /1000000

# %%
# bom_df.loc[:, 'domestic_gross'] = (bom_df.loc[:, 'domestic_gross'] / 1000000).copy()

# %%
# bom_df.loc[:, 'domestic_gross'] = bom_df.loc[:, 'domestic_gross'] / 1000000

# %%
bom_df.sort_values(by='foreign_gross', ascending=False)
# Out:
#                                             title studio  domestic_gross  \
# 328   Harry Potter and the Deathly Hallows Part 2     WB           381.0
# 1875                      Avengers: Age of Ultron     BV           459.0
# 727                         Marvel's The Avengers     BV           623.4
# 3081               Jurassic World: Fallen Kingdom   Uni.           417.7
# 1127                                       Frozen     BV           400.7
# ...                                           ...    ...             ...
# 2563                                 Mohenjo Daro    UTV             1.3
# 2562                                  Housefull 3   Eros             1.3
# 2561                       Embrace of the Serpent  Osci.             1.3
# 2560                               The Neon Demon     BG             1.3
# 3281                                 Lean on Pete    A24             1.2
#
#       foreign_gross  year
# 328           960.5  2011
# 1875          946.4  2015
# 727           895.5  2012
# 3081          891.8  2018
# 1127          875.7  2013
# ...             ...   ...
# 2563            0.0  2016
# 2562            0.0  2016
# 2561            0.0  2016
# 2560            0.0  2016
# 3281            0.0  2018
#
# [1763 rows x 5 columns]

# %%
bom_df['total_gross'] = (bom_df['domestic_gross'] + bom_df['foreign_gross'])

# %%
bom_df.sort_values(by=["studio", "total_gross"], ascending=True)
# Out:
#                                            title studio  domestic_gross  \
# 155   Sea Rex 3D: Journey to a Prehistoric World     3D             6.1
# 1736                                 The Captive    A24             1.1
# 1737                                     Laggies    A24             1.1
# 3281                                Lean on Pete    A24             1.2
# 1723                                       Locke    A24             1.4
# ...                                          ...    ...             ...
# 2406                                      Sultan   Yash             6.2
# 2835                             Tiger Zinda Hai   Yash             5.6
# 1204                                     Dhoom 3   Yash             8.0
# 2556                                      Rustom    Zee             1.1
# 584                     Bill Cunningham New York  Zeit.             1.5
#
#       foreign_gross  year  total_gross
# 155           9.900  2010       16.000
# 1736          0.000  2014        1.100
# 1737          0.000  2014        1.100
# 3281          0.000  2018        1.200
# 1723          0.000  2014        1.400
# ...             ...   ...          ...
# 2406         81.100  2016       87.300
# 2835         81.800  2017       87.400
# 1204         80.000  2013       88.000
# 2556          0.571  2016        1.671
# 584           0.000  2011        1.500
#
# [1763 rows x 6 columns]

# %% [markdown]
# # Incorrect way of trying to manipulate a groubpy object

# %%
# bom_df.groupby("studio").sort_values(by="total_gross", ascending=False)

# %% [markdown]
# # Most Profitable Studios

# %% [markdown]
# ### correct way to do it

# %%
bom_df.groupby("studio").agg(total_gross=("total_gross", "sum")).sort_values(by="total_gross", ascending=False)[:10]
# Out:
#           total_gross
# studio
# BV       42528.647998
# Fox      31005.366596
# WB       30833.702998
# Uni.     28521.667999
# Sony     21927.935997
# Par.     19521.384997
# WB (NL)  10334.699999
# LGF       8191.415300
# LG/S      5431.923998
# P/DW      5076.500000

# %% [markdown]
# ### New Line Cinema

# %%
bom_df[bom_df['studio'] == 'WB (NL)'].sort_values(by='total_gross', ascending=False)[:10]
# Out:
#                                           title   studio  domestic_gross  \
# 730           The Hobbit: An Unexpected Journey  WB (NL)      303.000000
# 1130        The Hobbit: The Desolation of Smaug  WB (NL)      258.399999
# 1478  The Hobbit: The Battle of the Five Armies  WB (NL)      255.100000
# 2770                                         It  WB (NL)      327.500000
# 1887                                San Andreas  WB (NL)      155.200000
# 3099                             Rampage (2018)  WB (NL)      101.000000
# 3104                                    The Nun  WB (NL)      117.500000
# 750            Journey 2: The Mysterious Island  WB (NL)      103.900000
# 2349                            The Conjuring 2  WB (NL)      102.500000
# 1149                              The Conjuring  WB (NL)      137.400000
#
#       foreign_gross  year  total_gross
# 730           718.1  2012  1021.100000
# 1130          700.0  2013   958.399999
# 1478          700.9  2014   956.000000
# 2770          372.9  2017   700.400000
# 1887          318.8  2015   474.000000
# 3099          327.0  2018   428.000000
# 3104          248.1  2018   365.600000
# 750           231.4  2012   335.300000
# 2349          217.9  2016   320.400000
# 1149          182.1  2013   319.500000

# %%
bom_df.title.duplicated().sum()
# Out:
# 0

# %%
# 114 unique studios
len(bom_df.studio.unique())
# Out:
# 114

# %%
# bom_df.studio.unique()

# %%
bom_df.sort_values(by="total_gross", ascending=False)[:20]
# Out:
#                                             title studio  domestic_gross  \
# 727                         Marvel's The Avengers     BV           623.4
# 1875                      Avengers: Age of Ultron     BV           459.0
# 3080                                Black Panther     BV           700.1
# 328   Harry Potter and the Deathly Hallows Part 2     WB           381.0
# 2758                     Star Wars: The Last Jedi     BV           620.2
# 3081               Jurassic World: Fallen Kingdom   Uni.           417.7
# 1127                                       Frozen     BV           400.7
# 2759                  Beauty and the Beast (2017)     BV           504.0
# 3082                                Incredibles 2     BV           608.6
# 1128                                   Iron Man 3     BV           409.0
# 1876                                      Minions   Uni.           336.0
# 2322                   Captain America: Civil War     BV           408.1
# 3083                                      Aquaman     WB           335.1
# 329                Transformers: Dark of the Moon   P/DW           352.4
# 728                                       Skyfall   Sony           304.4
# 1477              Transformers: Age of Extinction   Par.           245.4
# 729                         The Dark Knight Rises     WB           448.1
# 0                                     Toy Story 3     BV           415.0
# 2323                 Rogue One: A Star Wars Story     BV           532.2
# 330   Pirates of the Caribbean: On Stranger Tides     BV           241.1
#
#       foreign_gross  year  total_gross
# 727           895.5  2012       1518.9
# 1875          946.4  2015       1405.4
# 3080          646.9  2018       1347.0
# 328           960.5  2011       1341.5
# 2758          712.4  2017       1332.6
# 3081          891.8  2018       1309.5
# 1127          875.7  2013       1276.4
# 2759          759.5  2017       1263.5
# 3082          634.2  2018       1242.8
# 1128          805.8  2013       1214.8
# 1876          823.4  2015       1159.4
# 2322          745.2  2016       1153.3
# 3083          812.7  2018       1147.8
# 329           771.4  2011       1123.8
# 728           804.2  2012       1108.6
# 1477          858.6  2014       1104.0
# 729           636.8  2012       1084.9
# 0             652.0  2010       1067.0
# 2323          523.9  2016       1056.1
# 330           804.6  2011       1045.7

# %% [markdown]
# # 2nd CSV: "the numbers" movie budgets and gross values

# %%
tn_budgets_df = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
tn_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
tn_budgets_df.shape
# Out:
# (5782, 6)

# %%
tn_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# # Looks like near agreement on the total gross values between the two databases

# %%
tn_budgets_df[tn_budgets_df['movie'] == "Avengers: Age of Ultron"]
# Out:
#    id release_date                    movie production_budget domestic_gross  \
# 3   4  May 1, 2015  Avengers: Age of Ultron      $330,600,000   $459,005,868
#
#   worldwide_gross
# 3  $1,403,013,963

# %%
# FIRST DATABASE INFORMATION
bom_df[bom_df['title'] == "Avengers: Age of Ultron"]
# Out:
#                         title studio  domestic_gross  foreign_gross  year  \
# 1875  Avengers: Age of Ultron     BV           459.0          946.4  2015
#
#       total_gross
# 1875       1405.4

# %%
tn_budgets_df[tn_budgets_df['movie'] == "Avengers: Infinity War"]
# Out:
#    id  release_date                   movie production_budget domestic_gross  \
# 6   7  Apr 27, 2018  Avengers: Infinity War      $300,000,000   $678,815,482
#
#   worldwide_gross
# 6  $2,048,134,200

# %%
bom_df[bom_df['title'] == "Avengers: Infinity War"]
# Out:
# Empty DataFrame
# Columns: [title, studio, domestic_gross, foreign_gross, year, total_gross]
# Index: []

# %% [markdown]
# # Looks like near agreement on the total gross values between the two databases

# %%
bom_df[bom_df['title'].str.contains("Avatar")]
# Out:
#                        title studio  domestic_gross  foreign_gross  year  \
# 128  Avatar: Special Edition    Fox            10.7           22.5  2010
#
#      total_gross
# 128         33.2

# %% [markdown]
# # But not all items are the same

# %% [markdown]
# Need to convert columns to numeric: production_budget, domestic_gross, worldwide_gross

# %%
tn_budgets_df.head(2)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875

# %%
tn_budgets_df[['production_budget', 'domestic_gross', 'worldwide_gross']].head(2)
# Out:
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875

# %%
tn_budgets_df['production_budget'] = tn_budgets_df['production_budget'].str.replace('$', '').str.replace(',', '')
tn_budgets_df['domestic_gross'] = tn_budgets_df['domestic_gross'].str.replace('$', '').str.replace(',', '')
tn_budgets_df['worldwide_gross'] = tn_budgets_df['worldwide_gross'].str.replace('$', '').str.replace(',', '')

# %%
tn_budgets_df[['production_budget', 'domestic_gross', 'worldwide_gross']].head(2)
# Out:
#   production_budget domestic_gross worldwide_gross
# 0         425000000      760507625      2776345279
# 1         410600000      241063875      1045663875

# %%
tn_budgets_df[['production_budget', 'domestic_gross', 'worldwide_gross']].dtypes
# Out:
# production_budget    object
# domestic_gross       object
# worldwide_gross      object
# dtype: object

# %%
tn_budgets_df['production_budget'] = tn_budgets_df['production_budget'].astype(int)
tn_budgets_df['domestic_gross'] = tn_budgets_df['domestic_gross'].astype(int)
tn_budgets_df['worldwide_gross'] = tn_budgets_df['worldwide_gross'].astype(int)

# %%
tn_budgets_df[['production_budget', 'domestic_gross', 'worldwide_gross']].dtypes
# Out:
# production_budget    int64
# domestic_gross       int64
# worldwide_gross      int64
# dtype: object

# %% [markdown]
# # GROSS PROFIT COLUMN CREATION!

# %%
tn_budgets_df['gross_profit'] = 0
tn_budgets_df['gross_profit'] = tn_budgets_df['worldwide_gross'] - tn_budgets_df['production_budget']
tn_budgets_df['gross_profit'].agg(['max', 'min', 'mean'])
# Out:
# max     2.351345e+09
# min    -2.002376e+08
# mean    5.989970e+07
# Name: gross_profit, dtype: float64

# %%
tn_budgets_df.sort_values(by='gross_profit', ascending=False)
# Out:
#      id  release_date                                 movie  \
# 0     1  Dec 18, 2009                                Avatar
# 42   43  Dec 19, 1997                               Titanic
# 6     7  Apr 27, 2018                Avengers: Infinity War
# 5     6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens
# 33   34  Jun 12, 2015                        Jurassic World
# ..   ..           ...                                   ...
# 352  53  Apr 27, 2001                        Town & Country
# 341  42  Jun 14, 2019           Men in Black: International
# 193  94  Mar 11, 2011                       Mars Needs Moms
# 194  95  Dec 31, 2020                              Moonfall
# 2     3   Jun 7, 2019                          Dark Phoenix
#
#      production_budget  domestic_gross  worldwide_gross  gross_profit
# 0            425000000       760507625       2776345279    2351345279
# 42           200000000       659363944       2208208395    2008208395
# 6            300000000       678815482       2048134200    1748134200
# 5            306000000       936662225       2053311220    1747311220
# 33           215000000       652270625       1648854864    1433854864
# ..                 ...             ...              ...           ...
# 352          105000000         6712451         10364769     -94635231
# 341          110000000         3100000          3100000    -106900000
# 193          150000000        21392758         39549758    -110450242
# 194          150000000               0                0    -150000000
# 2            350000000        42762350        149762350    -200237650
#
# [5782 rows x 7 columns]

# %% [markdown]
# # FURTHER TRANSFORMATION!!!

# %% [markdown]
# # I think I will also divide these values by 1M

# %%
tn_budgets_df['production_budget'] = tn_budgets_df['production_budget'] / 1000000 
tn_budgets_df['domestic_gross'] = tn_budgets_df['domestic_gross'] / 1000000 
tn_budgets_df['worldwide_gross'] = tn_budgets_df['worldwide_gross'] / 1000000 
tn_budgets_df['gross_profit'] = tn_budgets_df['gross_profit'] / 1000000

# %%
tn_budgets_df['movie_year'] = tn_budgets_df['release_date'].map(lambda x: x[-4:]).astype(int)

# %%
tn_budgets_df['roi'] = tn_budgets_df['gross_profit'] / tn_budgets_df['production_budget']

# %%
tn_budgets_df['two_x'] = 0
tn_budgets_df['two_x'] = tn_budgets_df['roi'].map(lambda x: 1 if x >= 2 else 0)

# %%
tn_budgets_df.shape
# Out:
# (5782, 10)

# %% [markdown]
# # Getting rid of zero dom/world gross films

# %%
tn_budgets_df = tn_budgets_df.loc[tn_budgets_df['roi'] != -1]
tn_budgets_df.shape
# Out:
# (5415, 10)

# %%
tn_budgets_df['quartile'] = 0
tn_budgets_df["quartile"] = pd.qcut(tn_budgets_df["production_budget"], q=4, labels=["Bottom 25", "25-50", "50-75", "Top 25"])

# %%
len(tn_budgets_df.loc[tn_budgets_df['roi'] != -1])
# Out:
# 5415

# %%
tn_budgets_df.shape
# Out:
# (5415, 11)

# %%
tn_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  gross_profit  \
# 0              425.0      760.507625      2776.345279   2351.345279
# 1              410.6      241.063875      1045.663875    635.063875
# 2              350.0       42.762350       149.762350   -200.237650
# 3              330.6      459.005868      1403.013963   1072.413963
# 4              317.0      620.181382      1316.721747    999.721747
#
#    movie_year       roi  two_x quartile
# 0        2009  5.532577      1   Top 25
# 1        2011  1.546673      0   Top 25
# 2        2019 -0.572108      0   Top 25
# 3        2015  3.243841      1   Top 25
# 4        2017  3.153696      1   Top 25

# %% [markdown]
# Determined these movies revenue numbers unreliable

# %%
# full_loss = tn_budgets_df.loc[tn_budgets_df['roi'] == -1]
# full_loss.loc[full_loss['movie_year'] >= 2013].sort_values(by="movie_year", ascending=False)

# %%
tn_budgets_df.head(2)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
#
#    production_budget  domestic_gross  worldwide_gross  gross_profit  \
# 0              425.0      760.507625      2776.345279   2351.345279
# 1              410.6      241.063875      1045.663875    635.063875
#
#    movie_year       roi  two_x quartile
# 0        2009  5.532577      1   Top 25
# 1        2011  1.546673      0   Top 25

# %%
tn_budgets_df.sort_values(by='gross_profit', ascending=False)
# Out:
#      id  release_date                                 movie  \
# 0     1  Dec 18, 2009                                Avatar
# 42   43  Dec 19, 1997                               Titanic
# 6     7  Apr 27, 2018                Avengers: Infinity War
# 5     6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens
# 33   34  Jun 12, 2015                        Jurassic World
# ..   ..           ...                                   ...
# 404   5  Aug 16, 2002          The Adventures of Pluto Nash
# 352  53  Apr 27, 2001                        Town & Country
# 341  42  Jun 14, 2019           Men in Black: International
# 193  94  Mar 11, 2011                       Mars Needs Moms
# 2     3   Jun 7, 2019                          Dark Phoenix
#
#      production_budget  domestic_gross  worldwide_gross  gross_profit  \
# 0                425.0      760.507625      2776.345279   2351.345279
# 42               200.0      659.363944      2208.208395   2008.208395
# 6                300.0      678.815482      2048.134200   1748.134200
# 5                306.0      936.662225      2053.311220   1747.311220
# 33               215.0      652.270625      1648.854864   1433.854864
# ..                 ...             ...              ...           ...
# 404              100.0        4.411102         7.094995    -92.905005
# 352              105.0        6.712451        10.364769    -94.635231
# 341              110.0        3.100000         3.100000   -106.900000
# 193              150.0       21.392758        39.549758   -110.450242
# 2                350.0       42.762350       149.762350   -200.237650
#
#      movie_year        roi  two_x quartile
# 0          2009   5.532577      1   Top 25
# 42         1997  10.041042      1   Top 25
# 6          2018   5.827114      1   Top 25
# 5          2015   5.710167      1   Top 25
# 33         2015   6.669092      1   Top 25
# ..          ...        ...    ...      ...
# 404        2002  -0.929050      0   Top 25
# 352        2001  -0.901288      0   Top 25
# 341        2019  -0.971818      0   Top 25
# 193        2011  -0.736335      0   Top 25
# 2          2019  -0.572108      0   Top 25
#
# [5415 rows x 11 columns]

# %%
# Plotting Profit and Budget
fig, ax = plt.subplots(figsize=(24,10))
# Creates new df object to assist with plotting 
top_movies = tn_budgets_df.sort_values(by='gross_profit', ascending=False)[:10]

# Creates stacked bar plot showing total profit in blue, budget in yellow
sns.barplot(x='gross_profit', y='movie', data=top_movies, color='blue', ax=ax, label='Gross Profit')
sns.barplot(x='production_budget', y='movie', data=top_movies, color='orange', ax=ax, label='Production Budget')

# Labels and Titles
ax.set_xlabel("Gross Profit and Production Budget in Millions")
ax.set_ylabel("Movie Title")
ax.set_title("Top Ten Most Profitable Movies: Gross Profit vs Production Budget")
ax.legend()
plt.xticks(np.arange(0, 2420, 100));

# %% [markdown]
# # ADDING new column for ROI PROFIT/BUDGET

# %%
top_ten = tn_budgets_df.sort_values(by='roi', ascending=False)[:10]
top_ten
# Out:
#       id  release_date                     movie  production_budget  \
# 5745  46  Jun 30, 1972               Deep Throat              0.025
# 5613  14  Mar 21, 1980                   Mad Max              0.200
# 5492  93  Sep 25, 2009       Paranormal Activity              0.450
# 5679  80  Jul 10, 2015               The Gallows              0.100
# 5406   7  Jul 14, 1999   The Blair Witch Project              0.600
# 5709  10   May 7, 2004             Super Size Me              0.065
# 5346  47  Aug 13, 1942                     Bambi              0.858
# 5773  74  Feb 26, 1993               El Mariachi              0.007
# 5676  77   Oct 1, 1968  Night of the Living Dead              0.114
# 5210  11  Nov 21, 1976                     Rocky              1.000
#
#       domestic_gross  worldwide_gross  gross_profit  movie_year          roi  \
# 5745       45.000000        45.000000     44.975000        1972  1799.000000
# 5613        8.750000        99.750000     99.550000        1980   497.750000
# 5492      107.918810       194.183034    193.733034        2009   430.517853
# 5679       22.764410        41.656474     41.556474        2015   415.564740
# 5406      140.539099       248.300000    247.700000        1999   412.833333
# 5709       11.529368        22.233808     22.168808        2004   341.058585
# 5346      102.797000       268.000000    267.142000        1942   311.354312
# 5773        2.040920         2.041928      2.034928        1993   290.704000
# 5676       12.087064        30.087064     29.973064        1968   262.921614
# 5210      117.235147       225.000000    224.000000        1976   224.000000
#
#       two_x   quartile
# 5745      1  Bottom 25
# 5613      1  Bottom 25
# 5492      1  Bottom 25
# 5679      1  Bottom 25
# 5406      1  Bottom 25
# 5709      1  Bottom 25
# 5346      1  Bottom 25
# 5773      1  Bottom 25
# 5676      1  Bottom 25
# 5210      1  Bottom 25

# %%
tn_budgets_df.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  5415.000000        5415.000000     5415.000000      5415.000000
# mean     50.227701          33.308006       44.711279        97.687996
# std      28.765167          42.487580       69.609894       178.859114
# min       1.000000           0.001100        0.000000         0.000026
# 25%      25.000000           6.000000        3.160708         7.004834
# 50%      50.000000          19.000000       20.300218        33.339868
# 75%      75.000000          42.000000       55.782491       104.459004
# max     100.000000         425.000000      936.662225      2776.345279
#
#        gross_profit   movie_year          roi        two_x
# count   5415.000000  5415.000000  5415.000000  5415.000000
# mean      64.379990  2003.599446     4.125491     0.342752
# std      149.858055    12.546965    30.487420     0.474673
# min     -200.237650  1915.000000    -0.999974     0.000000
# 25%       -1.862081  1999.000000    -0.298948     0.000000
# 50%       11.900000  2006.000000     0.884921     0.000000
# 75%       67.379236  2012.000000     2.968780     1.000000
# max     2351.345279  2019.000000  1799.000000     1.000000

# %% [markdown]
# # How do i find more than 40.00000 budget/roi, and less than

# %%
sns.pairplot(tn_budgets_df.loc[tn_budgets_df['production_budget'] >= 40.000000000].drop(columns='id'));

# %%
sns.pairplot(tn_budgets_df.drop(columns="id"));

# %%
# reg plot for ALL movies profit/budget
sns.lmplot(y='gross_profit' , x='production_budget' , data=tn_budgets_df, line_kws={"color": "red"});

# %% [markdown]
# # Brake it into budget tiers

# %%
tn_budgets_df.shape
most_exp = tn_budgets_df.loc[tn_budgets_df['production_budget'] > 40.000]
inner_quartile = tn_budgets_df.loc[(tn_budgets_df['production_budget'] <= 40.000) & (
    tn_budgets_df['production_budget'] > 5.000)]
bottom_quartile = tn_budgets_df.loc[tn_budgets_df['production_budget'] <= 5.000]

# %%
tn_budgets_df.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  5415.000000        5415.000000     5415.000000      5415.000000
# mean     50.227701          33.308006       44.711279        97.687996
# std      28.765167          42.487580       69.609894       178.859114
# min       1.000000           0.001100        0.000000         0.000026
# 25%      25.000000           6.000000        3.160708         7.004834
# 50%      50.000000          19.000000       20.300218        33.339868
# 75%      75.000000          42.000000       55.782491       104.459004
# max     100.000000         425.000000      936.662225      2776.345279
#
#        gross_profit   movie_year          roi        two_x
# count   5415.000000  5415.000000  5415.000000  5415.000000
# mean      64.379990  2003.599446     4.125491     0.342752
# std      149.858055    12.546965    30.487420     0.474673
# min     -200.237650  1915.000000    -0.999974     0.000000
# 25%       -1.862081  1999.000000    -0.298948     0.000000
# 50%       11.900000  2006.000000     0.884921     0.000000
# 75%       67.379236  2012.000000     2.968780     1.000000
# max     2351.345279  2019.000000  1799.000000     1.000000

# %%
tn_budgets_df.head(2)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
#
#    production_budget  domestic_gross  worldwide_gross  gross_profit  \
# 0              425.0      760.507625      2776.345279   2351.345279
# 1              410.6      241.063875      1045.663875    635.063875
#
#    movie_year       roi  two_x quartile
# 0        2009  5.532577      1   Top 25
# 1        2011  1.546673      0   Top 25

# %%
tn_budgets_df['quartile'].value_counts()
# Out:
# Bottom 25    1371
# 50-75        1363
# 25-50        1351
# Top 25       1330
# Name: quartile, dtype: int64

# %%
tn_budgets_df.groupby("quartile").agg(["min", 'mean', 'max', 'std'])["production_budget"]
# Out:
#                min       mean    max        std
# quartile
# Bottom 25   0.0011   2.580697    6.0   1.863067
# 25-50       6.1000  12.151278   19.0   3.547459
# 50-75      19.1000  29.095657   42.0   6.951888
# Top 25     42.5000  90.790197  425.0  50.339778

# %%
tn_budgets_df.groupby("quartile").agg(["min", 'mean', 'max', 'std'])["production_budget"].plot(kind='bar');

# %%
tn_budgets_df.groupby("quartile").agg(["min", 'mean', 'max', 'std'])["roi"].plot(kind='bar');

# %%
most_exp.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  1362.000000        1362.000000     1362.000000      1362.000000
# mean     49.820117          89.640207      104.367868       258.848669
# std      28.642838          50.294337      101.668907       278.833648
# min       1.000000          41.000000        0.000000         0.022254
# 25%      25.000000          55.000000       37.911200        77.630309
# 50%      49.500000          72.000000       73.286518       166.957259
# 75%      74.000000         109.750000      134.180891       335.802261
# max     100.000000         425.000000      936.662225      2776.345279
#
#        gross_profit   movie_year          roi        two_x
# count   1362.000000  1362.000000  1362.000000  1362.000000
# mean     169.208463  2006.701909     1.708437     0.334802
# std      247.541462     7.400527     2.209224     0.472094
# min     -200.237650  1963.000000    -0.999521     0.000000
# 25%       12.402068  2001.000000     0.181405     0.000000
# 50%       95.059053  2007.000000     1.186625     0.000000
# 75%      228.080669  2013.000000     2.594779     1.000000
# max     2351.345279  2019.000000    15.489089     1.000000

# %%
# tn_budgets_df.sort_values(by='gross_profit', ascending=False)[:10]

# %%
top_coef = np.corrcoef(most_exp['production_budget'], most_exp['gross_profit'])
middle_coef = np.corrcoef(inner_quartile['production_budget'], inner_quartile['gross_profit'])
bottom_coef = np.corrcoef(bottom_quartile['production_budget'], bottom_quartile['gross_profit'])

print(f"""
The correlation between budget and profit for the TOP 25% of budgets is {top_coef[0][1]}.
The correlation between budget and profit for the INNER QUARTILE RANGE of budgets is {middle_coef[0][1]}.
The correlation between budget and profit for the BOTTOM 25% of budgets is {bottom_coef[0][1]}.""")
# Out:
# The correlation between budget and profit for the TOP 25% of budgets is 0.5599189597988767.
# The correlation between budget and profit for the INNER QUARTILE RANGE of budgets is 0.13819418606980372.
# The correlation between budget and profit for the BOTTOM 25% of budgets is 0.16729982408727181.

# %%
top_roi_coef = np.corrcoef(most_exp['production_budget'], most_exp['roi'])
middle_roi_coef = np.corrcoef(inner_quartile['production_budget'], inner_quartile['roi'])
bottom_roi_coef = np.corrcoef(bottom_quartile['production_budget'], bottom_quartile['roi'])

print(f"""
The correlation between budget and ROI for the TOP 25% of budgets is {top_roi_coef[0][1]}.
The correlation between budget and ROI for the INNER QUARTILE RANGE of budgets is {middle_roi_coef[0][1]}.
The correlation between budget and ROI for the BOTTOM 25% of budgets is {bottom_roi_coef[0][1]}.""")
# Out:
# The correlation between budget and ROI for the TOP 25% of budgets is 0.14467999757037522.
# The correlation between budget and ROI for the INNER QUARTILE RANGE of budgets is -0.10212001315350722.
# The correlation between budget and ROI for the BOTTOM 25% of budgets is -0.13326756709370383.

# %%
fig, ax = plt.subplots(ncols=3, figsize=(20,8))
sns.regplot(x="production_budget", y="gross_profit", data=most_exp, ax=ax[0], line_kws={"color": "red"})
ax[0].set_title("Highest Budget")
ax[0].axhline(y=0, color='red', linestyle='dotted')

sns.regplot(x="production_budget", y="gross_profit", data=inner_quartile, ax=ax[1], line_kws={"color": "red"})
ax[1].set_title("Inner-Quartile Budget")
ax[1].axhline(y=0, color='red', linestyle='dotted')

sns.regplot(x="production_budget", y="gross_profit", data=bottom_quartile, ax=ax[2], line_kws={"color": "red"})
ax[2].axhline(y=0, color='red', linestyle='dotted')
ax[2].set_title("Bottom Budget")

plt.subplots_adjust(hspace=0.0, wspace=.5)
plt.suptitle("Regression Lines Profit/Budget", fontsize=25)
plt.show();

# %% [markdown]
# # Percentage of Unprofitable Movies By Budget

# %% [markdown]
# # IMPORTANT

# %%
perc_loss_exp = len(most_exp.loc[most_exp['gross_profit'] <=0]) / len(most_exp)
perc_loss_mid = len(inner_quartile.loc[inner_quartile['gross_profit'] <=0]) / len(inner_quartile)
perc_loss_bot = len(bottom_quartile.loc[bottom_quartile['gross_profit'] <=0]) / len(bottom_quartile)

print("More Than 40M:", perc_loss_exp, "| Between 5-40M", perc_loss_mid, "| Less Than 5M", perc_loss_bot)
# Out:
# More Than 40M: 0.20704845814977973 | Between 5-40M 0.35444839857651245 | Less Than 5M 0.38616251005631536

# %%
most_exp.loc[most_exp['gross_profit'] >=0].describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  1080.000000        1080.000000     1080.000000      1080.000000
# mean     50.867593          94.804964      125.175670       315.341593
# std      28.434567          52.770759      104.268119       287.003036
# min       1.000000          41.000000        0.000000        46.414530
# 25%      27.000000          55.000000       57.374082       131.042272
# 50%      52.000000          78.000000       94.917101       215.931156
# 75%      75.000000         120.000000      155.923192       381.470714
# max     100.000000         425.000000      936.662225      2776.345279
#
#        gross_profit   movie_year          roi        two_x
# count   1080.000000  1080.000000  1080.000000  1080.000000
# mean     220.536629  2007.249074     2.262861     0.422222
# std      253.820639     7.343044     2.156261     0.494142
# min        0.047784  1963.000000     0.000265     0.000000
# 25%       59.593280  2002.000000     0.790861     0.000000
# 50%      136.144912  2008.000000     1.685764     0.000000
# 75%      278.380170  2013.000000     3.039606     1.000000
# max     2351.345279  2019.000000    15.489089     1.000000

# %% [markdown]
# # Modeling upper quartile of budgets

# %%
endog = most_exp['roi']  # dependent
exog = sm.add_constant(most_exp['production_budget'])  # independent
lin_reg_model = sm.OLS(endog, exog).fit()

# %%
lin_reg_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    roi   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     29.08
# Date:                Sun, 10 Sep 2023   Prob (F-statistic):           8.19e-08
# Time:                        23:15:38   Log-Likelihood:                -2997.3
# No. Observations:                1362   AIC:                             5999.
# Df Residuals:                    1360   BIC:                             6009.
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 1.1388      0.121      9.401      0.000       0.901       1.376
# production_budget     0.0064      0.001      5.392      0.000       0.004       0.009
# ==============================================================================
# Omnibus:                      636.281   Durbin-Watson:                   0.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3761.962
# Skew:                           2.125   Prob(JB):                         0.00
# Kurtosis:                       9.945   Cond. No.                         210.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# roi as a function of production budget, for every million spent, roi increases by .0065

sm.graphics.plot_regress_exog(lin_reg_model, 'production_budget', fig=plt.figure(figsize=(12, 8)));

# %% [markdown]
# applied to this data

# %%
# X = most_exp.loc[:, ["production_budget"]]
# ss = StandardScaler().fit(X)
# X_scaled = ss.transform(X)
# endog = most_exp['roi']  # dependent
# exog = sm.add_constant(X_scaled)  # independent
# lin_reg_model = sm.OLS(endog, exog)
# lin_reg_model.fit() 
# lin_reg_model.fit().summary()


X_c = sm.add_constant(most_exp['production_budget'])
y = most_exp['gross_profit']
model = sm.OLS(endog=y, exog=X_c).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           gross_profit   R-squared:                       0.314
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     621.1
# Date:                Sun, 10 Sep 2023   Prob (F-statistic):          3.15e-113
# Time:                        23:15:47   Log-Likelihood:                -9182.7
# No. Observations:                1362   AIC:                         1.837e+04
# Df Residuals:                    1360   BIC:                         1.838e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               -77.8256     11.365     -6.848      0.000    -100.121     -55.531
# production_budget     2.7558      0.111     24.922      0.000       2.539       2.973
# ==============================================================================
# Omnibus:                      533.074   Durbin-Watson:                   1.083
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3702.561
# Skew:                           1.655   Prob(JB):                         0.00
# Kurtosis:                      10.368   Cond. No.                         210.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# y = gross profit, x = production_budget, for every 1M spent, profit increases by 2.75M, 
# but there is a negative intercept

sm.graphics.plot_regress_exog(model, 'production_budget', fig=plt.figure(figsize=(12, 8)));

# %% [markdown]
# # Removing the outlier most profitable films

# %%
no_outliers = most_exp.loc[most_exp['gross_profit'] < 1000, 'gross_profit']
X_c = sm.add_constant(most_exp.loc[most_exp['gross_profit'] < 1000, 'production_budget'])
y = no_outliers
model_wo_outliers = sm.OLS(endog=y, exog=X_c).fit()

# %%
no_outliers.describe()
# Out:
# count    1345.000000
# mean      154.323385
# std       206.111299
# min      -200.237650
# 25%        11.971293
# 50%        90.808837
# 75%       221.872367
# max       999.721747
# Name: gross_profit, dtype: float64

# %% [markdown]
# # Model for films costing more than 40M and making less than 1B

# %%
model_wo_outliers.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           gross_profit   R-squared:                       0.255
# Model:                            OLS   Adj. R-squared:                  0.254
# Method:                 Least Squares   F-statistic:                     458.8
# Date:                Sun, 10 Sep 2023   Prob (F-statistic):           8.60e-88
# Time:                        23:16:03   Log-Likelihood:                -8877.1
# No. Observations:                1345   AIC:                         1.776e+04
# Df Residuals:                    1343   BIC:                         1.777e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               -37.4856     10.186     -3.680      0.000     -57.468     -17.503
# production_budget     2.1766      0.102     21.419      0.000       1.977       2.376
# ==============================================================================
# Omnibus:                      346.897   Durbin-Watson:                   1.041
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1138.906
# Skew:                           1.256   Prob(JB):                    4.89e-248
# Kurtosis:                       6.743   Cond. No.                         210.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sm.graphics.plot_regress_exog(model_wo_outliers, 'production_budget', fig=plt.figure(figsize=(12, 8)));

# %%
# same plot as above except plotting ROI/budget

no_outliers_roi = most_exp.loc[most_exp['gross_profit'] < 1000, 'roi']
X_c_roi = sm.add_constant(most_exp.loc[most_exp['gross_profit'] < 1000, 'production_budget'])
y = no_outliers_roi
roi_model_wo_outliers = sm.OLS(endog=y, exog=X_c_roi).fit()
roi_model_wo_outliers.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    roi   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     13.02
# Date:                Sun, 10 Sep 2023   Prob (F-statistic):           0.000320
# Time:                        23:16:17   Log-Likelihood:                -2907.8
# No. Observations:                1345   AIC:                             5820.
# Df Residuals:                    1343   BIC:                             5830.
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 1.2572      0.120     10.443      0.000       1.021       1.493
# production_budget     0.0043      0.001      3.608      0.000       0.002       0.007
# ==============================================================================
# Omnibus:                      624.035   Durbin-Watson:                   0.937
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3752.714
# Skew:                           2.098   Prob(JB):                         0.00
# Kurtosis:                      10.025   Cond. No.                         210.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Median 40M+ budget excluding outliers earns 1.16x ROI

# %%
no_outliers_roi.describe()
# Out:
# count    1345.000000
# mean        1.639038
# std         2.113168
# min        -0.999521
# 25%         0.170048
# 50%         1.163873
# 75%         2.517854
# max        15.489089
# Name: roi, dtype: float64

# %% [markdown]
# ### Pearson's Correlation for ROI and Budget = 0.098, almost .1, very low positive correlation

# %%
corr_check = most_exp.loc[most_exp['gross_profit'] < 1000, ["roi", "production_budget"]]
np.corrcoef(corr_check['roi'], corr_check['production_budget'])
# Out:
# array([[1.        , 0.09798536],
#        [0.09798536, 1.        ]])

# %%
sm.graphics.plot_regress_exog(roi_model_wo_outliers, 'production_budget', fig=plt.figure(figsize=(12, 8)));

# %%
sns.histplot(x='gross_profit', data=most_exp);

# %%
sns.histplot(x='roi', data=most_exp, bins='auto');

# %%
most_exp['roi'].max()
# Out:
# 15.489088634920636

# %% [markdown]
# # Identify top 10% of ROI's within each of the 3 budget tiers

# %%
exp_index = int(len(most_exp) - np.floor((.9 * len(most_exp))))
top_ten_perc_exp = most_exp.sort_values(by="roi", ascending = False)[:exp_index]
top_ten_perc_exp.shape
# Out:
# (137, 11)

# %%
mid_index = int(len(inner_quartile) - np.floor((.9 * len(inner_quartile))))
top_ten_perc_mid = inner_quartile.sort_values(by="roi", ascending = False)[:exp_index]
top_ten_perc_mid.shape
# Out:
# (137, 11)

# %%
bot_index = int(len(bottom_quartile) - np.floor((.9 * len(bottom_quartile))))
top_ten_perc_bot = bottom_quartile.sort_values(by="roi", ascending = False)[:exp_index]
top_ten_perc_bot.shape
# Out:
# (137, 11)

# %% [markdown]
# # Only looking at recent movies! - After the year 1996

# %%
top_ten_perc_bot.describe()
# Out:
#                id  production_budget  domestic_gross  worldwide_gross  \
# count  137.000000         137.000000      137.000000       137.000000
# mean    53.430657           1.589608       40.474730        70.107045
# std     26.840157           1.664005       45.184396        77.345275
# min      1.000000           0.001100        0.000000         0.181041
# 25%     30.000000           0.200000        7.159147        11.000000
# 50%     59.000000           1.000000       23.894000        42.411721
# 75%     75.000000           3.000000       55.683845        99.750000
# max    100.000000           5.000000      241.438208       390.525192
#
#        gross_profit   movie_year          roi  two_x
# count    137.000000   137.000000   137.000000  137.0
# mean      68.517436  1989.970803    85.769212    1.0
# std       76.252356    23.885124   171.602096    0.0
# min        0.179941  1915.000000    17.397750    1.0
# 25%       10.890000  1976.000000    25.028413    1.0
# 50%       41.556474  1998.000000    39.082500    1.0
# 75%       97.200000  2007.000000    85.566689    1.0
# max      386.625192  2018.000000  1799.000000    1.0

# %%
top_budget = top_ten_perc_exp.loc[top_ten_perc_exp['movie_year'] > 1996]
middle_budget = top_ten_perc_mid.loc[top_ten_perc_mid['movie_year'] > 1996]
bottom_budget = top_ten_perc_bot.loc[top_ten_perc_bot['movie_year'] > 1996]

# %%
top_budget.shape
# Out:
# (121, 11)

# %%
middle_budget.shape
# Out:
# (72, 11)

# %%
bottom_budget.shape
# Out:
# (76, 11)

# %%
top_budget.sort_values(by="gross_profit", ascending=False)[:12].describe()
# Out:
#               id  production_budget  domestic_gross  worldwide_gross  \
# count  12.000000          12.000000       12.000000        12.000000
# mean   32.666667         222.166667      588.969260      1691.575537
# std    22.398593          83.958684      178.807344       478.178564
# min     1.000000         125.000000      353.007020      1259.199706
# 25%    11.500000         167.500000      413.474322      1332.713068
# 50%    34.500000         200.000000      637.775086      1518.329346
# 75%    46.250000         243.750000      684.126503      2049.428455
# max    67.000000         425.000000      936.662225      2776.345279
#
#        gross_profit   movie_year        roi  two_x
# count     12.000000    12.000000  12.000000   12.0
# mean    1469.408870  2013.166667   6.919053    1.0
# std      405.750832     5.874960   1.521117    0.0
# min     1099.199706  1997.000000   5.532577    1.0
# 25%     1145.136868  2011.750000   5.745109    1.0
# 50%     1310.829346  2015.000000   6.675054    1.0
# 75%     1747.516965  2017.250000   7.115742    1.0
# max     2351.345279  2018.000000  10.041042    1.0

# %%
# Plotting Profit and Budget
fig, ax = plt.subplots(figsize=(24,10))
# Creates new df object to assist with plotting 
top_movies = top_budget.sort_values(by="gross_profit", ascending=False)[:12]

# Creates stacked bar plot showing total profit in blue, budget in yellow
sns.barplot(x='gross_profit', y='movie', data=top_movies, color='blue', ax=ax, label='Gross Profit')
sns.barplot(x='production_budget', y='movie', data=top_movies, color='orange', ax=ax, label='Production Budget')

# Labels and Titles
ax.set_xlabel("Gross Profit and Production Budget in Millions")
ax.set_ylabel("Movie Title")
ax.set_title("Top Ten Most Profitable Movies: Gross Profit vs Production Budget")
ax.legend()
plt.xticks(np.arange(0, 2420, 100));

# %%
middle_budget.sort_values(by="gross_profit", ascending=False)[:12].describe()
# Out:
#               id  production_budget  domestic_gross  worldwide_gross  \
# count  12.000000          12.000000       12.000000        12.000000
# mean   60.000000          28.983333      201.192135       504.098475
# std    32.777487          11.270382      100.645798       108.454469
# min     5.000000          10.800000       13.182281       384.530440
# 25%    24.750000          18.750000      140.697390       429.703667
# 50%    74.500000          35.000000      179.468542       461.635931
# 75%    84.500000          37.750000      281.368450       583.834057
# max    97.000000          40.000000      370.782930       697.457969
#
#        gross_profit   movie_year        roi  two_x
# count     12.000000    12.000000  12.000000   12.0
# mean     475.115141  2010.833333  19.497932    1.0
# std      104.703356     5.654175   9.917743    0.0
# min      365.280159  1999.000000   9.872437    1.0
# 25%      404.125765  2008.000000  11.990725    1.0
# 50%      424.135931  2011.000000  17.373764    1.0
# 75%      547.584057  2015.250000  24.536873    1.0
# max      662.457969  2018.000000  43.895652    1.0

# %%
# Plotting Profit and Budget
fig, ax = plt.subplots(figsize=(24,10))
# Creates new df object to assist with plotting 
top_movies = middle_budget.sort_values(by="gross_profit", ascending=False)[:12]

# Creates stacked bar plot showing total profit in blue, budget in yellow
sns.barplot(x='gross_profit', y='movie', data=top_movies, color='blue', ax=ax, label='Gross Profit')
sns.barplot(x='production_budget', y='movie', data=top_movies, color='orange', ax=ax, label='Production Budget')

# Labels and Titles
ax.set_xlabel("Gross Profit and Production Budget in Millions")
ax.set_ylabel("Movie Title")
ax.set_title("Top Ten Most Profitable Movies: Gross Profit vs Production Budget")
ax.legend()
plt.xticks(np.arange(0, 700, 100));
# Out:
# /Users/samalainabayeva/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/samalainabayeva/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/samalainabayeva/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/samalainabayeva/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
bottom_budget.sort_values(by="gross_profit", ascending=False)[:12]
# Out:
#       id  release_date                     movie  production_budget  \
# 4247  48  Apr 19, 2002  My Big Fat Greek Wedding               5.00
# 4249  50  Jan 20, 2017                     Split               5.00
# 4589  90  Aug 13, 1997            The Full Monty               3.50
# 4248  49  Feb 24, 2017                   Get Out               5.00
# 5406   7  Jul 14, 1999   The Blair Witch Project               0.60
# 4250  51  Oct 21, 2011     Paranormal Activity 3               5.00
# 5492  93  Sep 25, 2009       Paranormal Activity               0.45
# 4664  65  Oct 20, 2010     Paranormal Activity 2               3.00
# 4252  53  Sep 13, 2013       Insidious Chapter 2               5.00
# 4251  52  Oct 28, 2005                    Saw II               5.00
# 4254  55  Jul 22, 2016                Lights Out               5.00
# 4258  59  Oct 19, 2012     Paranormal Activity 4               5.00
#
#       domestic_gross  worldwide_gross  gross_profit  movie_year         roi  \
# 4247      241.438208       374.890034    369.890034        2002   73.978007
# 4249      138.141585       278.964806    273.964806        2017   54.792961
# 4589       45.950122       261.249383    257.749383        1997   73.642681
# 4248      176.040665       255.367951    250.367951        2017   50.073590
# 5406      140.539099       248.300000    247.700000        1999  412.833333
# 4250      104.028807       207.039844    202.039844        2011   40.407969
# 5492      107.918810       194.183034    193.733034        2009  430.517853
# 4664       84.752907       177.512032    174.512032        2010   58.170677
# 4252       83.586447       161.921515    156.921515        2013   31.384303
# 4251       87.025093       152.925093    147.925093        2005   29.585019
# 4254       67.268835       148.806510    143.806510        2016   28.761302
# 4258       53.900335       142.817992    137.817992        2012   27.563598
#
#       two_x   quartile
# 4247      1  Bottom 25
# 4249      1  Bottom 25
# 4589      1  Bottom 25
# 4248      1  Bottom 25
# 5406      1  Bottom 25
# 4250      1  Bottom 25
# 5492      1  Bottom 25
# 4664      1  Bottom 25
# 4252      1  Bottom 25
# 4251      1  Bottom 25
# 4254      1  Bottom 25
# 4258      1  Bottom 25

# %%
# Plotting Profit and Budget
fig, ax = plt.subplots(figsize=(24,10))
# Creates new df object to assist with plotting 
top_movies = bottom_budget.sort_values(by="gross_profit", ascending=False)[:12]

# Creates stacked bar plot showing total profit in blue, budget in yellow
sns.barplot(x='gross_profit', y='movie', data=top_movies, color='blue', ax=ax, label='Gross Profit')
sns.barplot(x='production_budget', y='movie', data=top_movies, color='orange', ax=ax, label='Production Budget')

# Labels and Titles
ax.set_xlabel("Gross Profit and Production Budget in Millions")
ax.set_ylabel("Movie Title")
ax.set_title("Top Ten Most Profitable Movies: Gross Profit vs Production Budget")
ax.legend()
plt.xticks(np.arange(0, 400, 100));

# %%
middle_budget.sort_values(by="gross_profit", ascending=False)[:25]
# Out:
#       id  release_date                               movie  production_budget  \
# 1623  24   Sep 8, 2017                                  It               35.0
# 1374  75   Aug 6, 1999                     The Sixth Sense               40.0
# 2159  60  Feb 25, 2004           The Passion of the Christ               25.0
# 1377  78  Feb 13, 2015                Fifty Shades of Grey               40.0
# 3517  18  May 25, 2012                    Les Intouchables               10.8
# 1624  25   Jun 5, 2009                        The Hangover               35.0
# 1382  83  Jul 25, 2014                                Lucy               40.0
# 2996  97  Nov 26, 2010                 The Kingâs Speech               15.0
# 2491  92   Dec 9, 2016                          La La Land               20.0
# 1604   5   Oct 5, 2018                      A Star is Born               36.0
# 3173  74  Nov 12, 2008                 Slumdog Millionaire               14.0
# 1588  89  Nov 21, 2008                            Twilight               37.0
# 2405   6  Jul 15, 1998        There's Something About Mary               22.0
# 2997  98  Sep 15, 1999                     American Beauty               15.0
# 3245  46   Dec 3, 2010                          Black Swan               13.0
# 2865  66   Apr 6, 2018                       A Quiet Place               17.0
# 2370  71  Nov 16, 2018                          Green Book               23.0
# 2492  93  Jul 19, 2013                       The Conjuring               20.0
# 3342  43   Jun 6, 2014              The Fault in Our Stars               12.0
# 3001   2  Aug 11, 2017                 Annabelle: Creation               15.0
# 3755  56  Dec 21, 2016                              Dangal                9.5
# 2494  95  Nov 17, 2017                              Wonder               20.0
# 3468  69  Oct 24, 2008  High School Musical 3: Senior Year               11.0
# 2725  26   Jul 7, 2000                         Scary Movie               19.0
# 2181  82  Apr 13, 2001               Bridget Jones's Diary               25.0
#
#       domestic_gross  worldwide_gross  gross_profit  movie_year        roi  \
# 1623      327.481748       697.457969    662.457969        2017  18.927371
# 1374      293.506292       672.806292    632.806292        1999  15.820157
# 2159      370.782930       622.341924    597.341924        2004  23.893677
# 1377      166.167230       570.998101    530.998101        2015  13.274953
# 3517       13.182281       484.873045    474.073045        2012  43.895652
# 1624      277.322503       465.764086    430.764086        2009  12.307545
# 1382      126.573960       457.507776    417.507776        2014  10.437694
# 2996      138.797449       430.821168    415.821168        2010  27.721411
# 2491      151.101803       426.351163    406.351163        2016  20.317558
# 1604      215.288866       433.449571    397.449571        2018  11.040266
# 3173      141.330703       384.530440    370.530440        2008  26.466460
# 1588      192.769854       402.280159    365.280159        2008   9.872437
# 2405      176.484651       369.884651    347.884651        1998  15.812939
# 2997      130.058047       356.258047    341.258047        1999  22.750536
# 3245      106.954678       331.266710    318.266710        2010  24.482055
# 2865      188.024361       334.522294    317.522294        2018  18.677782
# 2370       85.080171       322.034439    299.034439        2018  13.001497
# 2492      137.400141       318.000141    298.000141        2013  14.900007
# 3342      124.872350       307.166834    295.166834        2014  24.597236
# 3001      102.092201       305.384865    290.384865        2017  19.358991
# 3755       12.391761       294.654618    285.154618        2016  30.016276
# 2494      132.422809       304.604712    284.604712        2017  14.230236
# 3468       90.559416       274.392880    263.392880        2008  23.944807
# 2725      157.019771       277.200000    258.200000        2000  13.589474
# 2181       71.500556       281.527158    256.527158        2001  10.261086
#
#       two_x quartile
# 1623      1    50-75
# 1374      1    50-75
# 2159      1    50-75
# 1377      1    50-75
# 3517      1    25-50
# 1624      1    50-75
# 1382      1    50-75
# 2996      1    25-50
# 2491      1    50-75
# 1604      1    50-75
# 3173      1    25-50
# 1588      1    50-75
# 2405      1    50-75
# 2997      1    25-50
# 3245      1    25-50
# 2865      1    25-50
# 2370      1    50-75
# 2492      1    50-75
# 3342      1    25-50
# 3001      1    25-50
# 3755      1    25-50
# 2494      1    50-75
# 3468      1    25-50
# 2725      1    25-50
# 2181      1    50-75

# %%
bottom_budget.sort_values(by="gross_profit", ascending=False)[:25]
# Out:
#       id  release_date                       movie  production_budget  \
# 4247  48  Apr 19, 2002    My Big Fat Greek Wedding               5.00
# 4249  50  Jan 20, 2017                       Split               5.00
# 4589  90  Aug 13, 1997              The Full Monty               3.50
# 4248  49  Feb 24, 2017                     Get Out               5.00
# 5406   7  Jul 14, 1999     The Blair Witch Project               0.60
# 4250  51  Oct 21, 2011       Paranormal Activity 3               5.00
# 5492  93  Sep 25, 2009         Paranormal Activity               0.45
# 4664  65  Oct 20, 2010       Paranormal Activity 2               3.00
# 4252  53  Sep 13, 2013         Insidious Chapter 2               5.00
# 4251  52  Oct 28, 2005                      Saw II               5.00
# 4254  55  Jul 22, 2016                  Lights Out               5.00
# 4258  59  Oct 19, 2012       Paranormal Activity 4               5.00
# 4634  35  Jun 24, 2005     La marche de l'empereur               3.40
# 4257  58  Oct 13, 2017             Happy Death Day               5.00
# 4478  79  Sep 12, 2003         Lost in Translation               4.00
# 4281  82  Oct 13, 2000                Billy Elliot               5.00
# 4253  54  Mar 11, 2016         10 Cloverfield Lane               5.00
# 5156  57  Oct 29, 2004                         Saw               1.20
# 5211  12   Jan 6, 2012            The Devil Inside               1.00
# 5062  63   Apr 1, 2011                   Insidious               1.50
# 4259  60  Oct 24, 2014                       Ouija               5.00
# 4261  62  Aug 30, 2013  No se Aceptan Devoluciones               5.00
# 4255  56  Sep 11, 2015                   The Visit               5.00
# 4590  91  Apr 13, 2018               Truth or Dare               3.50
# 4666  67   Jun 7, 2013                   The Purge               3.00
#
#       domestic_gross  worldwide_gross  gross_profit  movie_year         roi  \
# 4247      241.438208       374.890034    369.890034        2002   73.978007
# 4249      138.141585       278.964806    273.964806        2017   54.792961
# 4589       45.950122       261.249383    257.749383        1997   73.642681
# 4248      176.040665       255.367951    250.367951        2017   50.073590
# 5406      140.539099       248.300000    247.700000        1999  412.833333
# 4250      104.028807       207.039844    202.039844        2011   40.407969
# 5492      107.918810       194.183034    193.733034        2009  430.517853
# 4664       84.752907       177.512032    174.512032        2010   58.170677
# 4252       83.586447       161.921515    156.921515        2013   31.384303
# 4251       87.025093       152.925093    147.925093        2005   29.585019
# 4254       67.268835       148.806510    143.806510        2016   28.761302
# 4258       53.900335       142.817992    137.817992        2012   27.563598
# 4634       77.437223       133.276359    129.876359        2005   38.198929
# 4257       55.683845       125.010260    120.010260        2017   24.002052
# 4478       44.585453       117.085297    113.085297        2003   28.271324
# 4281       21.995263       109.253745    104.253745        2000   20.850749
# 4253       72.082999       108.286422    103.286422        2016   20.657284
# 5156       55.968727       103.880027    102.680027        2004   85.566689
# 5211       53.262945       101.759490    100.759490        2012  100.759490
# 5062       54.009150        99.870886     98.370886        2011   65.580591
# 4259       50.856010       103.300632     98.300632        2014   19.660126
# 4261       44.467206       100.486616     95.486616        2013   19.097323
# 4255       65.206105        98.677816     93.677816        2015   18.735563
# 4590       41.411015        95.127344     91.627344        2018   26.179241
# 4666       64.473115        91.266581     88.266581        2013   29.422194
#
#       two_x   quartile
# 4247      1  Bottom 25
# 4249      1  Bottom 25
# 4589      1  Bottom 25
# 4248      1  Bottom 25
# 5406      1  Bottom 25
# 4250      1  Bottom 25
# 5492      1  Bottom 25
# 4664      1  Bottom 25
# 4252      1  Bottom 25
# 4251      1  Bottom 25
# 4254      1  Bottom 25
# 4258      1  Bottom 25
# 4634      1  Bottom 25
# 4257      1  Bottom 25
# 4478      1  Bottom 25
# 4281      1  Bottom 25
# 4253      1  Bottom 25
# 5156      1  Bottom 25
# 5211      1  Bottom 25
# 5062      1  Bottom 25
# 4259      1  Bottom 25
# 4261      1  Bottom 25
# 4255      1  Bottom 25
# 4590      1  Bottom 25
# 4666      1  Bottom 25

# %%
np.mean(most_exp['roi'])
most_exp.loc[
    most_exp['roi'] > np.mean(most_exp['roi']), 'roi'].agg(['min', 'max', 'mean'])
# Out:
# min      1.655949
# max     15.820157
# mean     3.680663
# Name: roi, dtype: float64

# %%
most_exp['roi'].describe()
# Out:
# count    1544.000000
# mean        1.654378
# std         2.244614
# min        -1.000000
# 25%         0.103835
# 50%         1.130493
# 75%         2.568507
# max        15.820157
# Name: roi, dtype: float64

# %%
most_exp.loc[
    most_exp['roi'] > np.mean(most_exp['roi']), 'roi'].sort_values(ascending=False)
# Out:
# 1374    15.820157
# 824     15.489089
# 983     15.272461
# 672     14.680219
# 1377    13.274953
#           ...
# 450      1.659711
# 145      1.659514
# 39       1.659504
# 778      1.658859
# 889      1.655949
# Name: roi, Length: 614, dtype: float64

# %%
most_exp[most_exp['two_x'] == 1]['roi'].sort_values(ascending=True)
# Out:
# 325      2.007091
# 273      2.008000
# 1139     2.008587
# 130      2.009161
# 1403     2.011400
#           ...
# 1377    13.274953
# 672     14.680219
# 983     15.272461
# 824     15.489089
# 1374    15.820157
# Name: roi, Length: 509, dtype: float64

# %%
most_exp[most_exp['two_x'] == 1]['roi'].describe()
# Out:
# count    509.000000
# mean       4.065081
# std        2.286014
# min        2.007091
# 25%        2.578242
# 50%        3.271344
# 75%        4.710397
# max       15.820157
# Name: roi, dtype: float64

# %%
most_exp['two_x'].value_counts(normalize=True)
# Out:
# 0    0.670337
# 1    0.329663
# Name: two_x, dtype: float64

# %%
sns.lmplot(x='production_budget', y='gross_profit', data=most_exp, hue='two_x', legend=False)
legend_labels = {True: 'ROI < 2', False: 'ROI > 2'}

plt.legend(title='ROI', labels=legend_labels.values());

# %%
sns.lmplot(x='production_budget', y='gross_profit', data=inner_quartile, hue='two_x', legend=False)
legend_labels = {True: 'ROI < 2', False: 'ROI > 2'}

plt.legend(title='ROI', labels=legend_labels.values());

# %%
most_exp['roi'].describe()
# Out:
# count    1544.000000
# mean        1.654378
# std         2.244614
# min        -1.000000
# 25%         0.103835
# 50%         1.130493
# 75%         2.568507
# max        15.820157
# Name: roi, dtype: float64

# %%
most_exp.head(2)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
#
#    production_budget  domestic_gross  worldwide_gross  gross_profit       roi  \
# 0              425.0      760.507625      2776.345279   2351.345279  5.532577
# 1              410.6      241.063875      1045.663875    635.063875  1.546673
#
#   price_tier quartile  two_x
# 0        425   Top 25      1
# 1      410.6   Top 25      0

# %%
tn_budgets_df.head(2)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
#
#    production_budget  domestic_gross  worldwide_gross  gross_profit       roi  \
# 0              425.0      760.507625      2776.345279   2351.345279  5.532577
# 1              410.6      241.063875      1045.663875    635.063875  1.546673
#
#    movie_year
# 0        2009
# 1        2011

# %%
tn_budgets_df.loc[tn_budgets_df['movie_year'] > 1996].groupby('movie_year')['roi'].agg("mean")
# Out:
# movie_year
# 1997    4.131997
# 1998    2.253871
# 1999    3.840196
# 2000    1.576391
# 2001    2.218931
# 2002    2.027330
# 2003    1.955383
# 2004    5.524860
# 2005    2.652111
# 2006    2.322708
# 2007    2.300398
# 2008    1.908336
# 2009    3.820398
# 2010    1.850538
# 2011    1.996947
# 2012    3.279592
# 2013    2.373171
# 2014    2.419511
# 2015    3.616905
# 2016    2.677948
# 2017    3.290137
# 2018    3.030495
# 2019    2.067200
# Name: roi, dtype: float64

# %%
sns.lineplot(x='movie_year', y='roi', data=tn_budgets_df.loc[tn_budgets_df['movie_year'] > 1996].groupby('movie_year').agg("mean"));

# %%
most_exp.loc[most_exp['movie_year'] > 1996].groupby('movie_year').agg("mean")['roi']
# Out:
# movie_year
# 1997    1.605274
# 1998    1.198870
# 1999    1.350597
# 2000    1.143432
# 2001    1.457008
# 2002    1.493873
# 2003    1.341243
# 2004    1.480142
# 2005    1.089354
# 2006    1.377513
# 2007    1.538331
# 2008    1.558230
# 2009    1.529763
# 2010    1.540638
# 2011    1.750729
# 2012    2.168335
# 2013    1.981238
# 2014    2.107082
# 2015    2.270353
# 2016    2.183604
# 2017    2.349798
# 2018    2.699786
# 2019    0.942465
# Name: roi, dtype: float64

# %% [markdown]
# "Blues_r"
# "Reds_r"
# "Purples_r"
# "Oranges_r"
# "Greys_r"
# "YlOrBr_r"
# "BuPu_r"
# "YlGnBu_r"
# "RdPu_r"
# "PuBuGn_r"
# greens = sns.color_palette("RdPu_r", 25)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(16,7))
plt.suptitle("Upper Quartile Budget Films")
color = sns.color_palette("RdPu_r", 25)

sns.lineplot(x='movie_year', y='roi', data=most_exp.loc[most_exp['movie_year'] > 1996].groupby(
    'movie_year').agg("mean"), ax=ax[0], palette=color)
sns.lineplot(x='movie_year', y='gross_profit', data=most_exp.loc[most_exp['movie_year'] > 1996].groupby(
    'movie_year').agg("mean"), ax=ax[1]);

# %%
fig, ax = plt.subplots(ncols=2, figsize=(16,7))
plt.suptitle("Inner Quartile Range Budget Films")

sns.lineplot(x='movie_year', y='roi', data=inner_quartile.loc[inner_quartile['movie_year'] > 1996].groupby(
    'movie_year').agg("mean"), ax=ax[0])
sns.lineplot(x='movie_year', y='gross_profit', data=inner_quartile.loc[inner_quartile['movie_year'] > 1996].groupby(
    'movie_year').agg("mean"), ax=ax[1]);

# %%
fig, ax = plt.subplots(ncols=2, figsize=(16,7))
plt.suptitle("Bottom Quartile Budget Films")
sns.lineplot(x='movie_year', y='roi', data=bottom_quartile.loc[bottom_quartile['movie_year'] > 1996].groupby(
    'movie_year').agg("mean"), ax=ax[0])
sns.lineplot(x='movie_year', y='gross_profit', data=bottom_quartile.loc[bottom_quartile['movie_year'] > 1996].groupby(
    'movie_year').agg("mean"), ax=ax[1]);

# %%
fig, ax = plt.subplots(figsize=(8,8))
sns.lineplot(x='movie_year', y='roi', data=most_exp.loc[most_exp['movie_year'] > 1996].groupby(
    'movie_year').agg("mean"), ax=ax, label="Upper Quartile")
sns.lineplot(x='movie_year', y='roi', data=inner_quartile.loc[inner_quartile['movie_year'] > 1996].groupby(
    'movie_year').agg("mean"), ax=ax, label="Inner Quartile Range")
sns.lineplot(x='movie_year', y='roi', data=bottom_quartile.loc[bottom_quartile['movie_year'] > 1996].groupby(
    'movie_year').agg("mean"), ax=ax, label = "Bottom Quartile");

# %%
sns.kdeplot(x='roi', data=most_exp, shade=True);

# %%
sns.histplot(x='roi', data=most_exp);

# %%
sns.lmplot(x='gross_profit' , y='production_budget' , data=most_exp);

# %%
sns.lmplot(x='production_budget' , y='roi' , data=most_exp);

# %%
sns.histplot(most_exp["roi"]);

# %%
sns.histplot(most_exp.loc[most_exp['roi'] > 2, "production_budget"]);

# %%
inner_quartile.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  2856.000000        2856.000000     2856.000000      2856.000000
# mean     50.931373          17.647674       29.223004        51.444425
# std      28.837989           9.296044       40.067638        74.578830
# min       1.000000           5.000000        0.000000         0.000000
# 25%      26.000000          10.000000        3.590625         8.283002
# 50%      51.000000          16.000000       16.308179        26.551624
# 75%      76.000000          25.000000       39.128652        63.840938
# max     100.000000          39.000000      460.998007       792.965326
#
#        gross_profit          roi
# count   2856.000000  2856.000000
# mean      33.796750     2.235714
# std       72.792265     5.428049
# min      -37.376626    -1.000000
# 25%       -5.391095    -0.454873
# 50%       10.111476     0.674682
# 75%       44.110979     2.648879
# max      782.465326    74.520507

# %%
mu = np.mean(inner_quartile['roi'])
sigma = np.std(inner_quartile['roi'])
n = len(inner_quartile)

fig, ax = plt.subplots
ax1 = stats.norm.pdf(alpha=.95, loc=mu, scale=sigma)
ax = ax1
ax.set_xticks(np.arange(stats.norm.cdf(.025), stats.norm.cdf(.975), 20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-147-da5741412e8d> in <module>
#       3 n = len(inner_quartile)
#       4
# ----> 5 fig, ax = plt.subplots
#       6 ax1 = stats.norm.pdf(alpha=.95, loc=mu, scale=sigma)
#       7 ax = ax1
#
# TypeError: cannot unpack non-iterable function object

# %%
sns.histplot(inner_quartile["roi"]);

# %%
sns.histplot(inner_quartile.loc[inner_quartile['roi'] > 2, "production_budget"], );

# %%
sns.lmplot(x='gross_profit' , y='production_budget' , data=inner_quartile);

# %%
bottom_quartile.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  1382.000000        1382.000000     1382.000000      1382.000000
# mean     49.965991           1.785378        6.066987         9.496835
# std      28.673464           1.370551       16.426260        26.992648
# min       1.000000           0.001100        0.000000         0.000000
# 25%      25.000000           0.500000        0.000449         0.008593
# 50%      50.000000           1.500000        0.320091         0.840535
# 75%      74.750000           3.000000        4.381074         7.588814
# max     100.000000           4.900000      198.680470       390.525192
#
#        gross_profit          roi
# count   1382.000000  1382.000000
# mean       7.711457     9.430517
# std       26.797903    59.514366
# min       -4.884802    -1.000000
# 25%       -1.008437    -0.988447
# 50%       -0.025159    -0.224250
# 75%        5.121463     4.073944
# max      386.625192  1799.000000

# %%
sns.histplot(bottom_quartile.loc[bottom_quartile['roi'] > 2, "production_budget"]);

# %%
tn_budgets_df.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  5782.000000        5782.000000     5782.000000      5782.000000
# mean     50.372363          31.587757       41.873327        91.487461
# std      28.821076          41.812077       68.240597       174.719969
# min       1.000000           0.001100        0.000000         0.000000
# 25%      25.000000           5.000000        1.429534         4.125415
# 50%      50.000000          17.000000       17.225945        27.984448
# 75%      75.000000          40.000000       52.348662        97.645837
# max     100.000000         425.000000      936.662225      2776.345279
#
#        gross_profit          roi
# count   5782.000000  5782.000000
# mean      59.899704     3.800161
# std      146.088881    29.530282
# min     -200.237650    -1.000000
# 25%       -2.189071    -0.507704
# 50%        8.550286     0.708310
# 75%       60.968502     2.758346
# max     2351.345279  1799.000000

# %%
sns.boxplot(y="gross_profit", x="quartile", data=tn_budgets_df);

# %%
# top_movies = tn_budgets_df.sort_values(by='gross_profit', ascending=False)[:10]

# # Creates stacked bar plot showing total profit in blue, budget in yellow
# sns.barplot(x='gross_profit', y='movie', data=top_movies, color='blue', ax=ax, label='Gross Profit')
# sns.barplot(x='production_budget', y='movie', data=top_movies, color='orange', ax=ax, label='Production Budget')

# # Labels and Titles
# ax.set_xlabel("Gross Profit and Production Budget in Millions")
# ax.set_ylabel("Movie Title")
# ax.set_title("Top Ten Most Profitable Movies: Gross Profit vs Production Budget")
# ax.legend()
# plt.xticks(np.arange(0, 2500, 100));

# %%
# chart illustrating the top 10 ROI's for movies in our data
greens = sns.color_palette("PuBuGn_r", 25)
fig, ax = plt.subplots(ncols=2, figsize=(20,10), gridspec_kw={'wspace': .5})

# chart ROI for highest ROI films
ax[0].set_yticklabels("")
sns.barplot(y='movie', x='roi', data=top_ten, ax=ax[0], color='purple')
ax[0].set_ylabel("")
ax[0].set_xlabel("Multiples of ROI")
ax[0].set_title("Return on Investment")

# chart gross profit
sns.barplot(y='movie', x='gross_profit', data=top_ten, ax=ax[1], color='purple')
ax[1].set_xlabel("Gross Profit in Millions")
ax[1].set_ylabel("")
ax[1].set_title("Earnings")

# stack budget on top of gross earnings
sns.barplot(y='movie', x='production_budget', data= top_ten, ax=ax[1], color='yellow');

# %%
five = top_ten.sort_values(by='production_budget', ascending=True)[:5]
sns.barplot(y='movie', x='production_budget', data=five);

# %%
blue = sns.color_palette("RdPu_r", 25)
sns.barplot(y='movie', x='production_budget', data= top_ten, ax=ax[1], palette=blue);

# %% [markdown]
# # Biggest nominal loss movies, 3 of which are streamers, so no box office

# %% [markdown]
# ## Going to drop data where domestic gross and worldwide gross = 0

# %%
no_streamers = tn_budgets_df.loc[(tn_budgets_df['domestic_gross'] != 0) & (tn_budgets_df['worldwide_gross'] != 0)]
ten_worst = no_streamers.sort_values(by='gross_profit', ascending=True)[:10]
ten_worst
# Out:
#      id  release_date                         movie  production_budget  \
# 2     3   Jun 7, 2019                  Dark Phoenix              350.0
# 193  94  Mar 11, 2011               Mars Needs Moms              150.0
# 341  42  Jun 14, 2019   Men in Black: International              110.0
# 352  53  Apr 27, 2001                Town & Country              105.0
# 404   5  Aug 16, 2002  The Adventures of Pluto Nash              100.0
# 477  78  Apr 21, 2017                   The Promise               90.0
# 607   8   Sep 2, 2005            A Sound of Thunder               80.0
# 435  36  Dec 22, 1995              Cutthroat Island               92.0
# 300   1  Dec 17, 2010              How Do You Know?              120.0
# 669  70  Feb 23, 2001                    Monkeybone               75.0
#
#      domestic_gross  worldwide_gross  gross_profit       roi
# 2         42.762350       149.762350   -200.237650 -0.572108
# 193       21.392758        39.549758   -110.450242 -0.736335
# 341        3.100000         3.100000   -106.900000 -0.971818
# 352        6.712451        10.364769    -94.635231 -0.901288
# 404        4.411102         7.094995    -92.905005 -0.929050
# 477        8.224288        10.551417    -79.448583 -0.882762
# 607        1.900451         6.300451    -73.699549 -0.921244
# 435       10.017322        18.517322    -73.482678 -0.798725
# 300       30.212620        49.628177    -70.371823 -0.586432
# 669        5.409517         5.409517    -69.590483 -0.927873

# %% [markdown]
# "Blues_r"
# "Reds_r"
# "Purples_r"
# "Oranges_r"
# "Greys_r"
# "YlOrBr_r"
# "BuPu_r"
# "YlGnBu_r"
# "RdPu_r"
# "PuBuGn_r"
# greens = sns.color_palette("RdPu_r", 25)

# %%
# plotting worst financial movies
# setting color, figsize
greens = sns.color_palette("RdPu_r", 25)
fig, ax = plt.subplots(ncols=2, figsize=(20,10), gridspec_kw={'wspace': .5})

# plot gross profit
sns.barplot(y='movie', x='gross_profit', data=ten_worst, ax=ax[0], palette=greens)
ax[0].set_xlabel("Gross Loss in Millions")
ax[0].set_ylabel("")
ax[0].set_title("Biggest Gross Losses")
ax[1].set_yticklabels("")

# plot loss on investment
sns.barplot(y='movie', x='roi', data=ten_worst.sort_values(by='gross_profit', ascending=True), ax=ax[1], palette=greens)
ax[1].set_ylabel("")
ax[1].set_xlabel("Gross Revenue Divided by Budget")
ax[1].set_title("Losses on Investment");

# %% [markdown]
# # 3rd CSV data exploration: rotten tomatoes

# %%
rt_movie_df = pd.read_csv('zippedData/rt.movie_info.tsv.gz', delimiter='\t')
rt_movie_df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
rt_movie_df.shape
# Out:
# (1560, 12)

# %%
rt_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %% [markdown]
# ### This df doesn't have movie titles at all, so needs to be joined with another table i think

# %%
rt_movie_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 4th CSV Next Piece of Data: Rotten tomatoes reviews

# %%
rt_reviews_df = pd.read_csv('zippedData/rt.reviews.tsv.gz', delimiter='\t', encoding='unicode_escape')
rt_reviews_df.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
rt_reviews_df['review'][0]
# Out:
# "A distinctly gallows take on contemporary financial mores, as one absurdly rich man's limo ride across town for a haircut functions as a state-of-the-nation discourse. "

# %%
rt_reviews_df.shape
# Out:
# (54432, 8)

# %%
rt_reviews_df.top_critic.value_counts()
# Out:
# 0    41336
# 1    13096
# Name: top_critic, dtype: int64

# %%
rt_movie_df['id'][0]
# Out:
# 1

# %%
rt_reviews_df['id'][0]
# Out:
# 3

# %% [markdown]
# # Separate the reviews by top_critics

# %%
top_critics = rt_reviews_df.loc[rt_reviews_df['top_critic'] == 1].copy()

# %%
top_critics.head()
# Out:
#     id                                             review rating   fresh  \
# 24   3  The rapid dialogue is dry and mannered, like a...  2.5/4  rotten
# 47   3  It feels like each and every moment bursts for...    2/4  rotten
# 50   3  There's not really a movie there, nothing that...    2/4  rotten
# 54   3  The film is all too faithful to its un-cinemat...  1.5/4  rotten
# 55   3  Cosmopolis," because of its allegiance to the ...    2/4  rotten
#
#              critic  top_critic                 publisher               date
# 24     Joe Williams           1   St. Louis Post-Dispatch  September 6, 2012
# 47  Stephanie Merry           1           Washington Post    August 24, 2012
# 50     Mick LaSalle           1   San Francisco Chronicle    August 23, 2012
# 54     Colin Covert           1  Minneapolis Star Tribune    August 23, 2012
# 55  Moira MacDonald           1             Seattle Times    August 23, 2012

# %%
top_critics.shape
# Out:
# (13096, 8)

# %% [markdown]
# # Top 48 critics all have more than 40 reviews logged

# %%
review_counts = top_critics.groupby('id').agg('sum')
review_counts.agg(['max', 'min', 'mean'])
review_counts.sort_values(by='top_critic', ascending=False)[40:49]
# Out:
#       top_critic
# id
# 1695          40
# 301           40
# 1525          40
# 1523          40
# 290           40
# 1496          40
# 1017          40
# 1009          40
# 65            39

# %%
review_counts.sort_values(by='top_critic', ascending=False)[:10]  # 54 is max value
# Out:
#       top_critic
# id
# 1777          54
# 1704          50
# 1646          49
# 1083          48
# 1071          47
# 1877          47
# 1545          47
# 251           47
# 1588          46
# 1808          46

# %%
rt_reviews_df.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
rt_movie_df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %% [markdown]
# # id column is unique identifyer for the rotten tomatoes dfs
# # rt_movie_df has a genre feature, could be useful- 300 unique values

# %%
review = top_critics[top_critics['id'] == 3]
title = rt_movie_df[rt_movie_df['id'] == 3]
# review

# %%
# title  # from rt_movie_df

# %%
sns.barplot(y=rt_movie_df['genre'].value_counts()[:10].index, x=rt_movie_df['genre'].value_counts()[:10]);

# %% [markdown]
# # 5th CSV: the movie db ('tmdb')

# %%
tmdb_df = pd.read_csv('zippedData/tmdb.movies.csv.gz')
tmdb_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
tmdb_df['popularity'].agg(['max', 'min', 'mean'])
# Out:
# max     80.773000
# min      0.600000
# mean     3.130912
# Name: popularity, dtype: float64

# %%
tmdb_df['vote_average'].agg(['max', 'min', 'mean'])
# Out:
# max     10.000000
# min      0.000000
# mean     5.991281
# Name: vote_average, dtype: float64

# %% [markdown]
# # Possibly Drop These

# %%
tmdb_df[tmdb_df['vote_average'] == 0]
# Out:
#        Unnamed: 0          genre_ids      id original_language  \
# 2467         2467                 []  331998                en
# 4078         4078  [28, 27, 878, 37]   57817                en
# 4282         4282               [35]   41840                en
# 5176         5176     [18, 9648, 53]  102678                en
# 5177         5177               [18]   81267                hi
# ...           ...                ...     ...               ...
# 26512       26512           [27, 18]  488143                en
# 26513       26513           [18, 53]  485975                en
# 26514       26514       [14, 28, 12]  381231                en
# 26515       26515    [10751, 12, 28]  366854                en
# 26516       26516           [53, 27]  309885                en
#
#                     original_title  popularity release_date  \
# 2467            Edie: Girl on Fire       0.600   2010-01-01
# 4078                     Red River       0.875   2011-05-05
# 4282   Tom Wilson: Bigger Than You       0.666   2011-12-09
# 5176                    Dead Write       0.600   2011-01-01
# 5177                          क्षय       0.600   2011-10-08
# ...                            ...         ...          ...
# 26512        Laboratory Conditions       0.600   2018-10-13
# 26513              _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                 The Last One       0.600   2018-10-01
# 26515                 Trailer Made       0.600   2018-06-22
# 26516                   The Church       0.600   2018-10-05
#
#                              title  vote_average  vote_count
# 2467            Edie: Girl on Fire           0.0           1
# 4078                     Red River           0.0           1
# 4282   Tom Wilson: Bigger Than You           0.0           1
# 5176                    Dead Write           0.0           1
# 5177                       Corrode           0.0           1
# ...                            ...           ...         ...
# 26512        Laboratory Conditions           0.0           1
# 26513              _EXHIBIT_84xxx_           0.0           1
# 26514                 The Last One           0.0           1
# 26515                 Trailer Made           0.0           1
# 26516                   The Church           0.0           1
#
# [136 rows x 10 columns]

# %%
tmdb_df[tmdb_df['vote_average'] == 0]
# Out:
#        Unnamed: 0          genre_ids      id original_language  \
# 2467         2467                 []  331998                en
# 4078         4078  [28, 27, 878, 37]   57817                en
# 4282         4282               [35]   41840                en
# 5176         5176     [18, 9648, 53]  102678                en
# 5177         5177               [18]   81267                hi
# ...           ...                ...     ...               ...
# 26512       26512           [27, 18]  488143                en
# 26513       26513           [18, 53]  485975                en
# 26514       26514       [14, 28, 12]  381231                en
# 26515       26515    [10751, 12, 28]  366854                en
# 26516       26516           [53, 27]  309885                en
#
#                     original_title  popularity release_date  \
# 2467            Edie: Girl on Fire       0.600   2010-01-01
# 4078                     Red River       0.875   2011-05-05
# 4282   Tom Wilson: Bigger Than You       0.666   2011-12-09
# 5176                    Dead Write       0.600   2011-01-01
# 5177                          क्षय       0.600   2011-10-08
# ...                            ...         ...          ...
# 26512        Laboratory Conditions       0.600   2018-10-13
# 26513              _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                 The Last One       0.600   2018-10-01
# 26515                 Trailer Made       0.600   2018-06-22
# 26516                   The Church       0.600   2018-10-05
#
#                              title  vote_average  vote_count
# 2467            Edie: Girl on Fire           0.0           1
# 4078                     Red River           0.0           1
# 4282   Tom Wilson: Bigger Than You           0.0           1
# 5176                    Dead Write           0.0           1
# 5177                       Corrode           0.0           1
# ...                            ...           ...         ...
# 26512        Laboratory Conditions           0.0           1
# 26513              _EXHIBIT_84xxx_           0.0           1
# 26514                 The Last One           0.0           1
# 26515                 Trailer Made           0.0           1
# 26516                   The Church           0.0           1
#
# [136 rows x 10 columns]

# %% [markdown]
# # Trying to use a logorhythmic model!

# %%
stats.lognorm.cdf(x=15.4, loc=np.mean(most_exp['roi']), s=np.std(most_exp['roi']))
# Out:
# 0.8816275069908828

# %%
shape, loc, scale = stats.lognorm.fit(most_exp['roi'])

# %%
shape, loc, scale
# Out:
# (0.6324309143898441, -1.597420655093153, 2.6970978284573457)

# %%
X_c = sm.add_constant(most_exp['production_budget'])
y = most_exp['gross_profit']
model = sm.Logit(endog=y, exog=X_c).fit()

# %%
#### 'x1' is the carat variable
sm.graphics.plot_regress_exog(model, 'x1', fig=plt.figure(figsize=(12, 8)));
