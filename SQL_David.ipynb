# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sqlite3
from zipfile import ZipFile # for unzipping the db.zip file
pd.set_option('display.max_columns', None) # show all columns when printing out dataframe
plt.style.use("fivethirtyeight")
import scipy.stats as stats

from mpl_toolkits import mplot3d
import sklearn.metrics as metrics
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
import os
import zipfile

# %%
print(os.listdir('zippedData'))
# Out:
# ['tmdb.movies.csv.gz', 'im.db', 'im.db.zip', 'rt.reviews.tsv.gz', 'rt.movie_info.tsv.gz', 'tn.movie_budgets.csv.gz', 'bom.movie_gross.csv.gz']

# %%
import zipfile

# Specify the path to the zip file
zip_file_path = 'zippedData/im.db.zip'

# Extract the SQLite database from the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall('zippedData')

# %%
conn = sqlite3.connect('zippedData/im.db')

# %%
schema = pd.read_sql("""
SELECT *
FROM
    sqlite_master;""", conn)
schema
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %% [markdown]
# # movie_basics

# %%
print(schema['sql'][0])
# Out:
# CREATE TABLE "movie_basics" (
# "movie_id" TEXT,
#   "primary_title" TEXT,
#   "original_title" TEXT,
#   "start_year" INTEGER,
#   "runtime_minutes" REAL,
#   "genres" TEXT
# )

# %%
pd.read_sql("""
SELECT * 
FROM
    movie_basics;"""
, conn)
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %% [markdown]
# # directors

# %%
print(schema['sql'][1])
# Out:
# CREATE TABLE "directors" (
# "movie_id" TEXT,
#   "person_id" TEXT
# )

# %%
pd.read_sql("""
SELECT * 
FROM
    directors;"""
, conn)
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0462036   nm1940585
# 2       tt0835418   nm0151540
# 3       tt0835418   nm0151540
# 4       tt0878654   nm0089502
# ...           ...         ...
# 291169  tt8999974  nm10122357
# 291170  tt9001390   nm6711477
# 291171  tt9001494  nm10123242
# 291172  tt9001494  nm10123248
# 291173  tt9004986   nm4993825
#
# [291174 rows x 2 columns]

# %% [markdown]
# # known_for

# %%
print(schema['sql'][2])
# Out:
# CREATE TABLE "known_for" (
# "person_id" TEXT,
#   "movie_id" TEXT
# )

# %%
pd.read_sql("""
SELECT * 
FROM
    known_for;"""
, conn)
# Out:
#          person_id   movie_id
# 0        nm0061671  tt0837562
# 1        nm0061671  tt2398241
# 2        nm0061671  tt0844471
# 3        nm0061671  tt0118553
# 4        nm0061865  tt0896534
# ...            ...        ...
# 1638255  nm9990690  tt9090932
# 1638256  nm9990690  tt8737130
# 1638257  nm9991320  tt8734436
# 1638258  nm9991320  tt9615610
# 1638259  nm9993380  tt8743182
#
# [1638260 rows x 2 columns]

# %% [markdown]
# # movie_akas

# %%
print(schema['sql'][3])
# Out:
# CREATE TABLE "movie_akas" (
# "movie_id" TEXT,
#   "ordering" INTEGER,
#   "title" TEXT,
#   "region" TEXT,
#   "language" TEXT,
#   "types" TEXT,
#   "attributes" TEXT,
#   "is_original_title" REAL
# )

# %%
pd.read_sql("""
SELECT * 
FROM
    movie_akas;"""
, conn)
# Out:
#          movie_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru   None
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención   None
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title
# 0            bg         None         None                0.0
# 1          None  imdbDisplay         None                0.0
# 2          None  imdbDisplay         None                0.0
# 3          None         None  short title                0.0
# 4          None  imdbDisplay         None                0.0
# ...         ...          ...          ...                ...
# 331698     None     original         None                1.0
# 331699       en  imdbDisplay         None                0.0
# 331700     None     original         None                1.0
# 331701     None         None         None                0.0
# 331702       en  imdbDisplay         None                0.0
#
# [331703 rows x 8 columns]

# %% [markdown]
# # movie_ratings

# %%
print(schema['sql'][4])
# Out:
# CREATE TABLE "movie_ratings" (
# "movie_id" TEXT,
#   "averagerating" REAL,
#   "numvotes" INTEGER
# )

# %% [markdown]
# # movie_ratings join to movie names on movie_id is a good idea to start

# %%
pd.read_sql("""
SELECT * 
FROM
    movie_ratings;"""
, conn)
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %% [markdown]
# # persons --- FIRST NOT TO HAVE movie_id

# %%
print(schema['sql'][5])
# Out:
# CREATE TABLE "persons" (
# "person_id" TEXT,
#   "primary_name" TEXT,
#   "birth_year" REAL,
#   "death_year" REAL,
#   "primary_profession" TEXT
# )

# %%
pd.read_sql("""
SELECT * 
FROM
    persons;"""
, conn)
# Out:
#         person_id         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
# [606648 rows x 5 columns]

# %% [markdown]
# # principals -- person_id key works to join persons

# %%
print(schema['sql'][6])
# Out:
# CREATE TABLE "principals" (
# "movie_id" TEXT,
#   "ordering" INTEGER,
#   "person_id" TEXT,
#   "category" TEXT,
#   "job" TEXT,
#   "characters" TEXT
# )

# %%
pd.read_sql("""
SELECT * 
FROM
    principals;"""
, conn)
# Out:
#           movie_id  ordering   person_id  category       job  \
# 0        tt0111414         1   nm0246005     actor      None
# 1        tt0111414         2   nm0398271  director      None
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor      None
# 4        tt0323808         1   nm3579312   actress      None
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor      None
# 1028182  tt9692684         2   nm4929530      self      None
# 1028183  tt9692684         3  nm10441594  director      None
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters
# 0                 ["The Man"]
# 1                        None
# 2                        None
# 3                        None
# 4            ["Beth Boothby"]
# ...                       ...
# 1028181  ["Ebenezer Scrooge"]
# 1028182   ["Herself","Regan"]
# 1028183                  None
# 1028184                  None
# 1028185                  None
#
# [1028186 rows x 6 columns]

# %% [markdown]
# # writers

# %%
print(schema['sql'][7])
# Out:
# CREATE TABLE "writers" (
# "movie_id" TEXT,
#   "person_id" TEXT
# )

# %%
pd.read_sql("""
SELECT * 
FROM
    writers;"""
, conn)
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0438973   nm0175726
# 2       tt0438973   nm1802864
# 3       tt0462036   nm1940585
# 4       tt0835418   nm0310087
# ...           ...         ...
# 255868  tt8999892  nm10122246
# 255869  tt8999974  nm10122357
# 255870  tt9001390   nm6711477
# 255871  tt9004986   nm4993825
# 255872  tt9010172   nm8352242
#
# [255873 rows x 2 columns]

# %%
# principals and persons on person_id
pd.read_sql("""
SELECT *
FROM
    principals
JOIN
    persons
ON
    principals.person_id = persons.person_id
WHERE
    category = "actor" OR category = "actress" OR category = "director";""", conn)
# Out:
#          movie_id  ordering   person_id  category   job  \
# 0       tt0111414         1   nm0246005     actor  None
# 1       tt0111414         2   nm0398271  director  None
# 2       tt0323808         1   nm3579312   actress  None
# 3       tt0323808         2   nm2694680     actor  None
# 4       tt0323808         3   nm0574615     actor  None
# ...           ...       ...         ...       ...   ...
# 549073  tt9689618         3  nm10439724     actor  None
# 549074  tt9689618         4   nm9652770  director  None
# 549075  tt9689618         5  nm10439725  director  None
# 549076  tt9692684         1   nm0186469     actor  None
# 549077  tt9692684         3  nm10441594  director  None
#
#                       characters   person_id      primary_name  birth_year  \
# 0                    ["The Man"]   nm0246005      Tommy Dysart         NaN
# 1                           None   nm0398271      Frank Howson      1952.0
# 2               ["Beth Boothby"]   nm3579312   Brittania Nicol         NaN
# 3              ["Steve Thomson"]   nm2694680     Henry Garrett         NaN
# 4       ["Sir Lachlan Morrison"]   nm0574615   Graham McTavish      1961.0
# ...                          ...         ...               ...         ...
# 549073                      None  nm10439724  Phillippe Warner         NaN
# 549074                      None   nm9652770      Xavi Herrero         NaN
# 549075                      None  nm10439725      Xavi Herrero         NaN
# 549076      ["Ebenezer Scrooge"]   nm0186469   Kenneth Cranham      1944.0
# 549077                      None  nm10441594         Guy Jones         NaN
#
#         death_year               primary_profession
# 0              NaN                            actor
# 1              NaN            actor,writer,producer
# 2              NaN               actress,soundtrack
# 3              NaN                            actor
# 4              NaN        actor,soundtrack,director
# ...            ...                              ...
# 549073         NaN                             None
# 549074         NaN  director,writer,cinematographer
# 549075         NaN  director,writer,cinematographer
# 549076         NaN                 actor,soundtrack
# 549077         NaN                         director
#
# [549078 rows x 11 columns]

# %%
pd.read_sql("""
SELECT *
FROM
    principals
JOIN
    persons
ON
    principals.person_id = persons.person_id
;""", conn)
# Out:
#           movie_id  ordering   person_id  category       job  \
# 0        tt0111414         1   nm0246005     actor      None
# 1        tt0111414         2   nm0398271  director      None
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor      None
# 4        tt0323808         1   nm3579312   actress      None
# ...            ...       ...         ...       ...       ...
# 1027907  tt9692684         1   nm0186469     actor      None
# 1027908  tt9692684         2   nm4929530      self      None
# 1027909  tt9692684         3  nm10441594  director      None
# 1027910  tt9692684         4   nm6009913    writer    writer
# 1027911  tt9692684         5  nm10441595  producer  producer
#
#                    characters   person_id           primary_name  birth_year  \
# 0                 ["The Man"]   nm0246005           Tommy Dysart         NaN
# 1                        None   nm0398271           Frank Howson      1952.0
# 2                        None   nm3739909  Barry Porter-Robinson         NaN
# 3                        None   nm0059247            Sean Barton      1944.0
# 4            ["Beth Boothby"]   nm3579312        Brittania Nicol         NaN
# ...                       ...         ...                    ...         ...
# 1027907  ["Ebenezer Scrooge"]   nm0186469        Kenneth Cranham      1944.0
# 1027908   ["Herself","Regan"]   nm4929530           Pearl Mackie      1987.0
# 1027909                  None  nm10441594              Guy Jones         NaN
# 1027910                  None   nm6009913        Sabrina Mahfouz         NaN
# 1027911                  None  nm10441595             Simmer Dim         NaN
#
#          death_year                              primary_profession
# 0               NaN                                           actor
# 1               NaN                           actor,writer,producer
# 2               NaN                         producer,art_department
# 3               NaN  editor,editorial_department,assistant_director
# 4               NaN                              actress,soundtrack
# ...             ...                                             ...
# 1027907         NaN                                actor,soundtrack
# 1027908         NaN                                         actress
# 1027909         NaN                                        director
# 1027910         NaN                                          writer
# 1027911         NaN                                        producer
#
# [1027912 rows x 11 columns]

# %% [markdown]
# # MOVIE RATINGS AND MOVIE AKAS

# %%
pd.read_sql("""
SELECT *
FROM
    movie_akas
JOIN
    movie_ratings
ON 
    movie_akas.movie_id = movie_ratings.movie_id
;""", conn)
# Out:
#          movie_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 261801  tt9726638         2                 Monkey King: The Volcano   None
# 261802  tt9726638         3            Qi Tian Da Sheng Huo Yan Shan     CN
# 261803  tt9827784         1                       Sayonara kuchibiru     JP
# 261804  tt9827784         2                       Sayonara kuchibiru   None
# 261805  tt9827784         3                            Farewell Song    XWW
#
#        language        types   attributes  is_original_title   movie_id  \
# 0            bg         None         None                0.0  tt0369610
# 1          None  imdbDisplay         None                0.0  tt0369610
# 2          None  imdbDisplay         None                0.0  tt0369610
# 3          None         None  short title                0.0  tt0369610
# 4          None  imdbDisplay         None                0.0  tt0369610
# ...         ...          ...          ...                ...        ...
# 261801     None     original         None                1.0  tt9726638
# 261802      yue  imdbDisplay         None                0.0  tt9726638
# 261803     None         None         None                0.0  tt9827784
# 261804     None     original         None                1.0  tt9827784
# 261805       en  imdbDisplay         None                0.0  tt9827784
#
#         averagerating  numvotes
# 0                 7.0    539338
# 1                 7.0    539338
# 2                 7.0    539338
# 3                 7.0    539338
# 4                 7.0    539338
# ...               ...       ...
# 261801            6.0         6
# 261802            6.0         6
# 261803            7.7         6
# 261804            7.7         6
# 261805            7.7         6
#
# [261806 rows x 11 columns]

# %%
# movie_ratings join to movie names on movie_id
pd.read_sql("""
SELECT title, region, averagerating as "Critic_Score" 
FROM
    movie_akas
JOIN
    movie_ratings
ON 
    movie_akas.movie_id = movie_ratings.movie_id
WHERE
    Critic_Score >= 7 AND
    region = "US"
ORDER BY 
    Critic_Score DESC
;""", conn)
# Out:
#                                                    title region  Critic_Score
# 0                                   Freeing Bernie Baran     US          10.0
# 1                                        Revolution Food     US          10.0
# 2                              Dog Days in the Heartland     US          10.0
# 3                                          All Around Us     US          10.0
# 4      Ellis Island: The Making of a Master Race in A...     US          10.0
# ...                                                  ...    ...           ...
# 10795                Department Q: A Conspiracy of Faith     US           7.0
# 10796                                           Meridian     US           7.0
# 10797                                   Just Say Goodbye     US           7.0
# 10798                                       Fearsville 2     US           7.0
# 10799                                          Pet Names     US           7.0
#
# [10800 rows x 3 columns]

# %%
# movie basics and movie ratings

# movie_basics

pd.read_sql("""
SELECT *
FROM
    movie_ratings
JOIN
    movie_basics
ON
    movie_ratings.movie_id = movie_basics.movie_id
;""", conn)
# Out:
#          movie_id  averagerating  numvotes    movie_id  \
# 0      tt10356526            8.3        31  tt10356526
# 1      tt10384606            8.9       559  tt10384606
# 2       tt1042974            6.4        20   tt1042974
# 3       tt1043726            4.2     50352   tt1043726
# 4       tt1060240            6.5        21   tt1060240
# ...           ...            ...       ...         ...
# 73851   tt9805820            8.1        25   tt9805820
# 73852   tt9844256            7.5        24   tt9844256
# 73853   tt9851050            4.7        14   tt9851050
# 73854   tt9886934            7.0         5   tt9886934
# 73855   tt9894098            6.3       128   tt9894098
#
#                                            primary_title  \
# 0                                       Laiye Je Yaarian
# 1                                             Borderless
# 2                                              Just Inès
# 3                                 The Legend of Hercules
# 4                                              Até Onde?
# ...                                                  ...
# 73851                                              Caisa
# 73852  Code Geass: Lelouch of the Rebellion - Glorifi...
# 73853                                            Sisters
# 73854                                  The Projectionist
# 73855                                             Sathru
#
#                                          original_title  start_year  \
# 0                                      Laiye Je Yaarian        2019
# 1                                            Borderless        2019
# 2                                             Just Inès        2010
# 3                                The Legend of Hercules        2014
# 4                                             Até Onde?        2011
# ...                                                 ...         ...
# 73851                                             Caisa        2018
# 73852  Code Geass: Lelouch of the Rebellion Episode III        2018
# 73853                                           Sisters        2019
# 73854                                 The Projectionist        2019
# 73855                                            Sathru        2019
#
#        runtime_minutes                    genres
# 0                117.0                   Romance
# 1                 87.0               Documentary
# 2                 90.0                     Drama
# 3                 99.0  Action,Adventure,Fantasy
# 4                 73.0          Mystery,Thriller
# ...                ...                       ...
# 73851             84.0               Documentary
# 73852            120.0   Action,Animation,Sci-Fi
# 73853              NaN              Action,Drama
# 73854             81.0               Documentary
# 73855            129.0                  Thriller
#
# [73856 rows x 9 columns]

# %%
pd.read_sql("""
SELECT MAX(numvotes) as max_votes, MIN(numvotes) as min_votes, AVG(numvotes) as avg_votes
FROM
    movie_ratings
JOIN
    movie_basics
ON
    movie_ratings.movie_id = movie_basics.movie_id
;""", conn)
# Out:
#    max_votes  min_votes    avg_votes
# 0    1841066          5  3523.662167

# %%
pd.read_sql("""
SELECT MAX(averagerating) as max_rating, MIN(averagerating) as min_rating, AVG(averagerating) as avg_rating
FROM
    movie_ratings
JOIN
    movie_basics
ON
    movie_ratings.movie_id = movie_basics.movie_id
;""", conn)
# Out:
#    max_rating  min_rating  avg_rating
# 0        10.0         1.0    6.332729

# %%
pd.read_sql("""
SELECT DISTINCT(genres), AVG(averagerating) AS genre_rating, AVG(runtime_minutes) as Runtime
FROM
    movie_ratings
JOIN
    movie_basics
ON
    movie_ratings.movie_id = movie_basics.movie_id
GROUP BY
    genres
HAVING numvotes > AVG(numvotes)
ORDER BY
    genre_rating DESC
LIMIT 10
;""", conn)
# Out:
#                          genres  genre_rating     Runtime
# 0  Animation,Documentary,Family      8.320000   75.600000
# 1         Comedy,Family,Western      8.150000   97.500000
# 2    Documentary,Drama,Thriller      8.133333   89.000000
# 3     Action,Documentary,Family      8.080000   82.400000
# 4            Action,Romance,War      7.866667  133.333333
# 5     Adventure,Fantasy,Musical      7.850000  131.000000
# 6     Biography,Documentary,War      7.812500   81.250000
# 7        Action,Fantasy,History      7.750000  101.500000
# 8       Documentary,Family,News      7.721053   76.578947
# 9    Documentary,Mystery,Sci-Fi      7.700000   72.000000

# %%
pd.read_sql("""
SELECT AVG(averagerating) AS genre_rating, AVG(runtime_minutes) as Runtime
FROM
    movie_ratings
JOIN
    movie_basics
ON
    movie_ratings.movie_id = movie_basics.movie_id
WHERE 
    genres LIKE "%Drama%"
;""", conn)
# Out:
#    genre_rating    Runtime
# 0      6.401559  98.434247

# %%
pd.read_sql("""
SELECT *
FROM
    movie_ratings
JOIN
    movie_basics
ON
    movie_ratings.movie_id = movie_basics.movie_id
WHERE 
    genres = "Comedy,Documentary,Fantasy"
;""", conn)
# Out:
#     movie_id  averagerating  numvotes   movie_id  primary_title  \
# 0  tt4135932            9.4         5  tt4135932  Lost Conquest
#
#   original_title  start_year  runtime_minutes                      genres
# 0  Lost Conquest        2015             70.0  Comedy,Documentary,Fantasy
